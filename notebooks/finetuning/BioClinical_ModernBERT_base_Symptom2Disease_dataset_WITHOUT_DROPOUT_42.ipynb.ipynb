# %% [markdown]
# # 🔧 Environment Setup
#
# Install core libraries for fine-tuning BioClinical ModernBERT on a symptom→disease classification task.
#
# **Main Packages**
# - `transformers` – model + Trainer utilities
# - `datasets` – dataset loading & mapping
# - `torch` – deep learning backend
# - `scikit-learn` – metrics & evaluation
# - `optuna` – hyperparameter optimization
# - `evaluate` – standardized metric interface
# - `wandb` – experiment tracking (optional)
# - `pandas`, `numpy` – data manipulation
# - `matplotlib`, `seaborn` – plotting
#
# Run the install cell below once (reuse cached env afterwards). Keep dependencies minimal to reduce startup time.

# %%
# %pip install transformers datasets torch scikit-learn kagglehub pandas numpy keras matplotlib seaborn nbformat optuna evaluate wandb wandb[core]
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (5.10.4)
# Collecting optuna
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.22.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras) (3.15.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras) (0.17.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras) (0.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat) (5.7.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.0)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.11.10)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.42.1)
# WARNING: wandb 0.22.2 does not provide the extra 'core'
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (0.28.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 12.5 MB/s eta 0:00:00
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.8 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna, evaluate
# Successfully installed colorlog-6.10.1 evaluate-0.4.6 optuna-4.5.0

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: qltpagsuguiron (qltpagsuguiron-technological-institute-of-the-philippines) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# # 📊 Dataset Preprocessing
#
# Prepare the symptom→disease dataset for supervised classification.
#
# **Steps**
# 1. Load filtered English dataset from Hugging Face.
# 2. Keep only `text` (symptom description) + `label` (disease).
# 3. Build `label2id` / `id2label` mappings; convert labels to integer `labels` field.
# 4. Split: 80% train / 10% validation / 10% test (seed=42 for reproducibility).
#
# Outputs:
# - Clean splits stored in a Python dict `dataset` with keys: `train`, `validation`, `test`.
# - Consistent integer label space used throughout training & evaluation.

# %%
from datasets import load_dataset
from transformers import set_seed

set_seed(42)

full_dataset = load_dataset("notlath/eng_dataset")

def preprocess_labels(example):
    # Use the correct column names from the dataset
    return {
        'text': example['text'],      # Use the actual 'text' column
        'label': example['label']     # Use the actual 'label' column
    }

# Apply preprocessing
processed_dataset = full_dataset['train'].map(preprocess_labels)

# Get unique labels and create mappings
unique_labels = list(set(processed_dataset['label']))
label2id = {label: i for i, label in enumerate(unique_labels)}
id2label = {i: label for label, i in label2id.items()}

# Convert labels to integers
def convert_labels_to_ids(example):
    return {
        'text': example['text'],
        'labels': label2id[example['label']]  # Convert to integer and rename to 'labels'
    }

processed_dataset = processed_dataset.map(convert_labels_to_ids, remove_columns=['label'])

# Split the dataset into train (75%), validation (15%), and test (15%)
train_test_split = processed_dataset.train_test_split(test_size=0.3, seed=42) # Split off 30% for test+validation
test_valid_split = train_test_split['test'].train_test_split(test_size=0.5, seed=42) # Split the 30% equally

dataset = {
    'train': train_test_split['train'],
    'validation': test_valid_split['train'],
    'test': test_valid_split['test']
}

print(dataset)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/473k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]
# {'train': Dataset({
#     features: ['text', 'labels'],
#     num_rows: 2100
# }), 'validation': Dataset({
#     features: ['text', 'labels'],
#     num_rows: 450
# }), 'test': Dataset({
#     features: ['text', 'labels'],
#     num_rows: 450
# })}

# %%
print("Original dataset columns:")
print(full_dataset['train'].column_names)
print("\nFirst few examples from original dataset:")
for i in range(3):
    print(f"Example {i}: {full_dataset['train'][i]}")
# Out:
# Original dataset columns:
# ['label', 'text']
#
# First few examples from original dataset:
# Example 0: {'label': 'Dengue', 'text': "A 100.2°F fever began two days ago, bringing with it a mild headache and some stiffness in my elbows. I'm feeling a bit run down with some mild fatigue, and my appetite has slightly decreased, but there are no other significant symptoms."}
# Example 1: {'label': 'Dengue', 'text': "A 100.3°F fever has been present for the last two days, along with a mild, dull headache. My joints are a little stiff, and I've developed a very slight, dry cough. Overall, I feel unwell and a bit fatigued, and my appetite has slightly decreased, but it's manageable."}
# Example 2: {'label': 'Dengue', 'text': "A 100.5°F fever and a mild headache started two days ago. My knees feel a little sore, but my movement is fine. I'm also a bit tired and my appetite is not what it usually is, but the symptoms are mild enough that I can get through most of my daily tasks."}

# %%
print("Dataset structure:")
print(dataset)
print("\nSample data from train:")
print(dataset["train"][0])
print(f"Type of text field: {type(dataset['train'][0]['text'])}")
print(f"Text content: {dataset['train'][0]['text']}")
# Out:
# Dataset structure:
# {'train': Dataset({
#     features: ['text', 'labels'],
#     num_rows: 2100
# }), 'validation': Dataset({
#     features: ['text', 'labels'],
#     num_rows: 450
# }), 'test': Dataset({
#     features: ['text', 'labels'],
#     num_rows: 450
# })}
#
# Sample data from train:
# {'text': 'What I thought was just the flu started three days ago with a 101.3°F fever. Yesterday, however, I began feeling an excruciating pain deep behind my eyes every time I turn my head. My knees also started to grind painfully when I go down the stairs. Just this morning, I found red speckles scattered over my lower back that were not there before I showered.', 'labels': 0}
# Type of text field: <class 'str'>
# Text content: What I thought was just the flu started three days ago with a 101.3°F fever. Yesterday, however, I began feeling an excruciating pain deep behind my eyes every time I turn my head. My knees also started to grind painfully when I go down the stairs. Just this morning, I found red speckles scattered over my lower back that were not there before I showered.

# %% [markdown]
# # 🤖 Model Setup & Tokenization
#
# **Model**: `thomas-sounack/BioClinical-ModernBERT-base` (domain‑adapted BERT variant for clinical/biomedical text).
#
# **Tokenization**
# - Apply tokenizer to all splits with truncation + dynamic padding.
# - Remove raw `text` after encoding; retain `input_ids`, `attention_mask`, `labels`.
#
# **Goal**: Produce uniform, batched tensors ready for `AutoModelForSequenceClassification`.
#
# Result: `tokenized_dataset` mirrors original splits with encoded features.

# %%
from transformers import AutoTokenizer

model_id = "thomas-sounack/BioClinical-ModernBERT-base"
# Remove conflicting parameters from tokenizer initialization
tokenizer = AutoTokenizer.from_pretrained(model_id)

def tokenize(examples):
    return tokenizer(
        examples["text"],
        truncation=True,
        padding=True,
    )

# Apply tokenize to each dataset split
tokenized_dataset = {}
for split, data in dataset.items():
    tokenized_dataset[split] = data.map(tokenize, batched=True, remove_columns=["text"])

print(tokenized_dataset)
print("Features:", tokenized_dataset["train"].features.keys())
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/693 [00:00<?, ?B/s]
# Map:   0%|          | 0/2100 [00:00<?, ? examples/s]
# Map:   0%|          | 0/450 [00:00<?, ? examples/s]
# Map:   0%|          | 0/450 [00:00<?, ? examples/s]
# {'train': Dataset({
#     features: ['labels', 'input_ids', 'attention_mask'],
#     num_rows: 2100
# }), 'validation': Dataset({
#     features: ['labels', 'input_ids', 'attention_mask'],
#     num_rows: 450
# }), 'test': Dataset({
#     features: ['labels', 'input_ids', 'attention_mask'],
#     num_rows: 450
# })}
# Features: dict_keys(['labels', 'input_ids', 'attention_mask'])

# %%
from transformers import AutoModelForSequenceClassification

unique_labels = tokenized_dataset["train"].unique("labels")
num_labels = len(unique_labels)

model = AutoModelForSequenceClassification.from_pretrained(
    model_id, num_labels=num_labels, label2id=label2id, id2label=id2label,
)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/599M [00:00<?, ?B/s]
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # 🔍 Hyperparameter Optimization
#
# Optimize training for validation accuracy using Optuna (TPE sampler, persistent SQLite storage).
#
# **Objective**: Maximize `eval_accuracy`.
#
# **Fixed Regularization**: All dropout variants set to 0.1.
#
# **Search Space**
# - Learning rate: log-uniform [2e-5, 8e-5]
# - Train batch size: {64, 128}
# - Weight decay: uniform [0.15, 0.35]
#
# **Process**
# 1. `model_init` supplies fresh model each trial (ensures comparable starts).
# 2. Trainer runs one configuration → records metrics.
# 3. Best trial exported to `hyperparameters.txt` for reuse.
#
# Result: `best_run` object with chosen LR, batch size, weight decay.

# %%
# %pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.5.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)

# %%
import optuna
from optuna.storages import RDBStorage
from optuna.samplers import TPESampler

sampler = TPESampler(seed=42)

# Define persistent storage
storage = RDBStorage("sqlite:///optuna_trials.db")

study = optuna.create_study(
    study_name="transformers_optuna_study", direction="maximize", storage=storage, load_if_exists=True, sampler=sampler
)
# Out:
# [I 2025-11-05 00:58:32,902] A new study created in RDB with name: transformers_optuna_study

# %%
# %pip install evaluate
# Out:
# Requirement already satisfied: evaluate in /usr/local/lib/python3.12/dist-packages (0.4.6)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)

# %%
import numpy as np
from sklearn.metrics import f1_score, precision_score, recall_score
import evaluate

metric = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    predictions = eval_pred.predictions.argmax(axis=-1)
    labels = eval_pred.label_ids
    return metric.compute(predictions=predictions, references=labels)

def compute_objective(metrics):
    return metrics["eval_accuracy"]
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]

# %%
from transformers import Trainer, TrainingArguments, DataCollatorWithPadding, AutoModelForSequenceClassification, AutoTokenizer

model_id = "thomas-sounack/BioClinical-ModernBERT-base"
# Define tokenizer here
tokenizer = AutoTokenizer.from_pretrained(model_id)

# Define data_collator here
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# Define num_labels, label2id, and id2label here
unique_labels = dataset["train"].unique("labels")
num_labels = len(unique_labels)
# Assuming label2id and id2label were created in a previous successful cell.
# If not, they would need to be recreated here based on unique_labels.
# Based on the provided notebook state, label2id and id2label are available.

training_args = TrainingArguments(
    per_device_train_batch_size=32,
    per_device_eval_batch_size=16,
    learning_rate=5e-5,
    num_train_epochs=5,
    weight_decay=0.01,
    seed=42,
    output_dir="./results",
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    logging_strategy="epoch",
    report_to="wandb",
    logging_dir="./logs",
    run_name="transformers_optuna_study",
)

def optuna_hp_space(trial):
    return {
        "learning_rate": trial.suggest_float("learning_rate", 2e-5, 8e-5, log=True),
        "per_device_train_batch_size": trial.suggest_categorical("per_device_train_batch_size", [16, 32]),
        "weight_decay": trial.suggest_float("weight_decay", 0.15, 0.35),
    }

def model_init(trial=None):
    return AutoModelForSequenceClassification.from_pretrained(
        model_id,
        num_labels=num_labels,
        label2id=label2id,
        id2label=id2label,
        attention_dropout=0.0,      # ✅ Correct parameter name
        mlp_dropout=0.0,             # ✅ Correct parameter name (not hidden_dropout)
        embedding_dropout=0.0,       # ✅ Optional but recommended
        classifier_dropout=0.0,      # ✅ Keep this
    )

trainer = Trainer(
    # Pass model_init instead of model
    model_init=model_init,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["validation"],
    compute_metrics=compute_metrics,
    data_collator=data_collator,
)
# Out:
# Flattening the indices:   0%|          | 0/2100 [00:00<?, ? examples/s]
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
best_run = trainer.hyperparameter_search(
    direction="maximize",
    backend="optuna",
    hp_space=optuna_hp_space,
    n_trials=8,  # 🔥 INCREASED from 5 to 8
    compute_objective=compute_objective,
    study_name="transformers_optuna_study",
    storage="sqlite:///optuna_trials.db",
    load_if_exists=True,
)

print(best_run)
# Out:
# [I 2025-11-05 00:58:54,887] Using an existing study with name 'transformers_optuna_study' instead of creating a new one.
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Currently logged in as: qltpagsuguiron (qltpagsuguiron-technological-institute-of-the-philippines) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251105_005907-w8m6ajis</code>
# Syncing run <strong><a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/w8m6ajis' target="_blank">graceful-rain-316</a></strong> to <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a>
#  View run at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/w8m6ajis' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/w8m6ajis</a>
# W1105 00:59:25.260000 1385 torch/_inductor/utils.py:1436] [1/0_1] Not enough SMs to use max_autotune_gemm mode
#     <div>
#
#       <progress value='660' max='660' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [660/660 10:25, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.404300</td>
#       <td>0.128979</td>
#       <td>0.964444</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.062500</td>
#       <td>0.080433</td>
#       <td>0.982222</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.017600</td>
#       <td>0.027306</td>
#       <td>0.988889</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.004500</td>
#       <td>0.031994</td>
#       <td>0.991111</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000200</td>
#       <td>0.033520</td>
#       <td>0.991111</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-11-05 01:09:56,500] Trial 0 finished with value: 0.9911111111111112 and parameters: {'learning_rate': 6.153875526724761e-05, 'per_device_train_batch_size': 16, 'weight_decay': 0.2763432701209472}. Best is trial 0 with value: 0.9911111111111112.
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▆▇██</td></tr><tr><td>eval/loss</td><td>█▅▁▁▁</td></tr><tr><td>eval/runtime</td><td>█▁▁▁▁</td></tr><tr><td>eval/samples_per_second</td><td>▁████</td></tr><tr><td>eval/steps_per_second</td><td>▁████</td></tr><tr><td>train/epoch</td><td>▁▁▃▃▅▅▆▆███</td></tr><tr><td>train/global_step</td><td>▁▁▃▃▅▅▆▆███</td></tr><tr><td>train/grad_norm</td><td>█▃▂▁▁</td></tr><tr><td>train/learning_rate</td><td>█▆▅▃▁</td></tr><tr><td>train/loss</td><td>█▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.99111</td></tr><tr><td>eval/loss</td><td>0.03352</td></tr><tr><td>eval/runtime</td><td>6.3952</td></tr><tr><td>eval/samples_per_second</td><td>70.365</td></tr><tr><td>eval/steps_per_second</td><td>4.535</td></tr><tr><td>total_flos</td><td>1390689968598000.0</td></tr><tr><td>train/epoch</td><td>5</td></tr><tr><td>train/global_step</td><td>660</td></tr><tr><td>train/grad_norm</td><td>0.0</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>+5</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">graceful-rain-316</strong> at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/w8m6ajis' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/w8m6ajis</a><br> View project at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251105_005907-w8m6ajis/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251105_010958-2snp5p0g</code>
# Syncing run <strong><a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/2snp5p0g' target="_blank">tough-morning-318</a></strong> to <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a>
#  View run at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/2snp5p0g' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/2snp5p0g</a>
#     <div>
#
#       <progress value='330' max='330' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [330/330 10:24, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.457100</td>
#       <td>0.226806</td>
#       <td>0.935556</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.070700</td>
#       <td>0.092612</td>
#       <td>0.977778</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.014000</td>
#       <td>0.069153</td>
#       <td>0.977778</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.001900</td>
#       <td>0.074306</td>
#       <td>0.982222</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000100</td>
#       <td>0.075289</td>
#       <td>0.980000</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-11-05 01:20:26,329] Trial 1 finished with value: 0.98 and parameters: {'learning_rate': 5.732957081118793e-05, 'per_device_train_batch_size': 32, 'weight_decay': 0.3207501071933744}. Best is trial 0 with value: 0.9911111111111112.
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▇▇██</td></tr><tr><td>eval/loss</td><td>█▂▁▁▁</td></tr><tr><td>eval/runtime</td><td>▅▂▁▇█</td></tr><tr><td>eval/samples_per_second</td><td>▄▇█▂▁</td></tr><tr><td>eval/steps_per_second</td><td>▄▇█▂▁</td></tr><tr><td>train/epoch</td><td>▁▁▃▃▅▅▆▆███</td></tr><tr><td>train/global_step</td><td>▁▁▃▃▅▅▆▆███</td></tr><tr><td>train/grad_norm</td><td>█▅▁▁▁</td></tr><tr><td>train/learning_rate</td><td>█▆▅▃▁</td></tr><tr><td>train/loss</td><td>█▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.98</td></tr><tr><td>eval/loss</td><td>0.07529</td></tr><tr><td>eval/runtime</td><td>6.3746</td></tr><tr><td>eval/samples_per_second</td><td>70.593</td></tr><tr><td>eval/steps_per_second</td><td>4.549</td></tr><tr><td>total_flos</td><td>1390689968598000.0</td></tr><tr><td>train/epoch</td><td>5</td></tr><tr><td>train/global_step</td><td>330</td></tr><tr><td>train/grad_norm</td><td>6e-05</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>+5</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">tough-morning-318</strong> at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/2snp5p0g' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/2snp5p0g</a><br> View project at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251105_010958-2snp5p0g/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251105_012028-qyf8c704</code>
# Syncing run <strong><a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/qyf8c704' target="_blank">soft-cloud-319</a></strong> to <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a>
#  View run at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/qyf8c704' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/qyf8c704</a>
#     <div>
#
#       <progress value='330' max='330' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [330/330 10:10, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.451800</td>
#       <td>0.186414</td>
#       <td>0.935556</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.062300</td>
#       <td>0.080283</td>
#       <td>0.975556</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.016600</td>
#       <td>0.078300</td>
#       <td>0.975556</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.008200</td>
#       <td>0.057662</td>
#       <td>0.982222</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000500</td>
#       <td>0.057283</td>
#       <td>0.982222</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-11-05 01:30:42,158] Trial 2 finished with value: 0.9822222222222222 and parameters: {'learning_rate': 5.579645987963028e-05, 'per_device_train_batch_size': 32, 'weight_decay': 0.18801543010523683}. Best is trial 0 with value: 0.9911111111111112.
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▇▇██</td></tr><tr><td>eval/loss</td><td>█▂▂▁▁</td></tr><tr><td>eval/runtime</td><td>▁▆▃▆█</td></tr><tr><td>eval/samples_per_second</td><td>█▃▆▃▁</td></tr><tr><td>eval/steps_per_second</td><td>█▃▆▃▁</td></tr><tr><td>train/epoch</td><td>▁▁▃▃▅▅▆▆███</td></tr><tr><td>train/global_step</td><td>▁▁▃▃▅▅▆▆███</td></tr><tr><td>train/grad_norm</td><td>█▂▁▁▁</td></tr><tr><td>train/learning_rate</td><td>█▆▄▃▁</td></tr><tr><td>train/loss</td><td>█▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.98222</td></tr><tr><td>eval/loss</td><td>0.05728</td></tr><tr><td>eval/runtime</td><td>6.4379</td></tr><tr><td>eval/samples_per_second</td><td>69.898</td></tr><tr><td>eval/steps_per_second</td><td>4.505</td></tr><tr><td>total_flos</td><td>1390689968598000.0</td></tr><tr><td>train/epoch</td><td>5</td></tr><tr><td>train/global_step</td><td>330</td></tr><tr><td>train/grad_norm</td><td>0.0011</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>+5</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">soft-cloud-319</strong> at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/qyf8c704' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/qyf8c704</a><br> View project at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251105_012028-qyf8c704/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251105_013048-48io7vcs</code>
# Syncing run <strong><a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/48io7vcs' target="_blank">glad-violet-320</a></strong> to <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a>
#  View run at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/48io7vcs' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/48io7vcs</a>
#     <div>
#
#       <progress value='330' max='330' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [330/330 09:54, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.493000</td>
#       <td>0.245832</td>
#       <td>0.928889</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.072300</td>
#       <td>0.140672</td>
#       <td>0.971111</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.015800</td>
#       <td>0.058548</td>
#       <td>0.982222</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.003800</td>
#       <td>0.064925</td>
#       <td>0.980000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.002900</td>
#       <td>0.064029</td>
#       <td>0.986667</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-11-05 01:40:46,947] Trial 3 finished with value: 0.9866666666666667 and parameters: {'learning_rate': 3.496136541248246e-05, 'per_device_train_batch_size': 32, 'weight_decay': 0.2510987147483367}. Best is trial 0 with value: 0.9911111111111112.
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▆▇▇█</td></tr><tr><td>eval/loss</td><td>█▄▁▁▁</td></tr><tr><td>eval/runtime</td><td>▆▁▁▅█</td></tr><tr><td>eval/samples_per_second</td><td>▃██▄▁</td></tr><tr><td>eval/steps_per_second</td><td>▃██▄▁</td></tr><tr><td>train/epoch</td><td>▁▁▃▃▅▅▆▆███</td></tr><tr><td>train/global_step</td><td>▁▁▃▃▅▅▆▆███</td></tr><tr><td>train/grad_norm</td><td>█▁▂▁▁</td></tr><tr><td>train/learning_rate</td><td>█▆▄▃▁</td></tr><tr><td>train/loss</td><td>█▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.98667</td></tr><tr><td>eval/loss</td><td>0.06403</td></tr><tr><td>eval/runtime</td><td>6.401</td></tr><tr><td>eval/samples_per_second</td><td>70.302</td></tr><tr><td>eval/steps_per_second</td><td>4.531</td></tr><tr><td>total_flos</td><td>1390689968598000.0</td></tr><tr><td>train/epoch</td><td>5</td></tr><tr><td>train/global_step</td><td>330</td></tr><tr><td>train/grad_norm</td><td>0.00129</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>+5</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glad-violet-320</strong> at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/48io7vcs' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/48io7vcs</a><br> View project at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251105_013048-48io7vcs/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251105_014048-82iig5dt</code>
# Syncing run <strong><a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/82iig5dt' target="_blank">kind-plasma-321</a></strong> to <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a>
#  View run at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/82iig5dt' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/82iig5dt</a>
#     <div>
#
#       <progress value='660' max='660' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [660/660 10:38, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.399000</td>
#       <td>0.162526</td>
#       <td>0.955556</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.064400</td>
#       <td>0.039483</td>
#       <td>0.980000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.017600</td>
#       <td>0.060052</td>
#       <td>0.973333</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.004700</td>
#       <td>0.060684</td>
#       <td>0.977778</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000300</td>
#       <td>0.056428</td>
#       <td>0.982222</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-11-05 01:51:31,195] Trial 4 finished with value: 0.9822222222222222 and parameters: {'learning_rate': 3.631989217229466e-05, 'per_device_train_batch_size': 16, 'weight_decay': 0.3378354751541459}. Best is trial 0 with value: 0.9911111111111112.
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▇▆▇█</td></tr><tr><td>eval/loss</td><td>█▁▂▂▂</td></tr><tr><td>eval/runtime</td><td>▃▄█▁▇</td></tr><tr><td>eval/samples_per_second</td><td>▆▅▁█▂</td></tr><tr><td>eval/steps_per_second</td><td>▆▅▁█▂</td></tr><tr><td>train/epoch</td><td>▁▁▃▃▅▅▆▆███</td></tr><tr><td>train/global_step</td><td>▁▁▃▃▅▅▆▆███</td></tr><tr><td>train/grad_norm</td><td>▂█▂▂▁</td></tr><tr><td>train/learning_rate</td><td>█▆▄▃▁</td></tr><tr><td>train/loss</td><td>█▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.98222</td></tr><tr><td>eval/loss</td><td>0.05643</td></tr><tr><td>eval/runtime</td><td>6.4407</td></tr><tr><td>eval/samples_per_second</td><td>69.869</td></tr><tr><td>eval/steps_per_second</td><td>4.503</td></tr><tr><td>total_flos</td><td>1390689968598000.0</td></tr><tr><td>train/epoch</td><td>5</td></tr><tr><td>train/global_step</td><td>660</td></tr><tr><td>train/grad_norm</td><td>0.00098</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>+5</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">kind-plasma-321</strong> at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/82iig5dt' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/82iig5dt</a><br> View project at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251105_014048-82iig5dt/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251105_015132-gg6l3kfq</code>
# Syncing run <strong><a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/gg6l3kfq' target="_blank">dauntless-snowball-322</a></strong> to <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a>
#  View run at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/gg6l3kfq' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/gg6l3kfq</a>
#     <div>
#
#       <progress value='66' max='330' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 66/330 01:41 < 06:59, 0.63 it/s, Epoch 1/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.533800</td>
#       <td>0.260121</td>
#       <td>0.926667</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-11-05 01:53:17,146] Trial 5 pruned.
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁</td></tr><tr><td>eval/loss</td><td>▁</td></tr><tr><td>eval/runtime</td><td>▁</td></tr><tr><td>eval/samples_per_second</td><td>▁</td></tr><tr><td>eval/steps_per_second</td><td>▁</td></tr><tr><td>train/epoch</td><td>▁▁</td></tr><tr><td>train/global_step</td><td>▁▁</td></tr><tr><td>train/grad_norm</td><td>▁</td></tr><tr><td>train/learning_rate</td><td>▁</td></tr><tr><td>train/loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.92667</td></tr><tr><td>eval/loss</td><td>0.26012</td></tr><tr><td>eval/runtime</td><td>6.3902</td></tr><tr><td>eval/samples_per_second</td><td>70.42</td></tr><tr><td>eval/steps_per_second</td><td>4.538</td></tr><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/global_step</td><td>66</td></tr><tr><td>train/grad_norm</td><td>2.72836</td></tr><tr><td>train/learning_rate</td><td>3e-05</td></tr><tr><td>train/loss</td><td>0.5338</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dauntless-snowball-322</strong> at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/gg6l3kfq' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/gg6l3kfq</a><br> View project at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251105_015132-gg6l3kfq/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251105_015318-ob3u7vi7</code>
# Syncing run <strong><a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/ob3u7vi7' target="_blank">robust-snowball-323</a></strong> to <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a>
#  View run at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/ob3u7vi7' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/ob3u7vi7</a>
#     <div>
#
#       <progress value='66' max='330' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 66/330 01:41 < 06:58, 0.63 it/s, Epoch 1/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.522600</td>
#       <td>0.223466</td>
#       <td>0.933333</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-11-05 01:55:02,625] Trial 6 pruned.
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁</td></tr><tr><td>eval/loss</td><td>▁</td></tr><tr><td>eval/runtime</td><td>▁</td></tr><tr><td>eval/samples_per_second</td><td>▁</td></tr><tr><td>eval/steps_per_second</td><td>▁</td></tr><tr><td>train/epoch</td><td>▁▁</td></tr><tr><td>train/global_step</td><td>▁▁</td></tr><tr><td>train/grad_norm</td><td>▁</td></tr><tr><td>train/learning_rate</td><td>▁</td></tr><tr><td>train/loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.93333</td></tr><tr><td>eval/loss</td><td>0.22347</td></tr><tr><td>eval/runtime</td><td>6.388</td></tr><tr><td>eval/samples_per_second</td><td>70.445</td></tr><tr><td>eval/steps_per_second</td><td>4.54</td></tr><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/global_step</td><td>66</td></tr><tr><td>train/grad_norm</td><td>3.52934</td></tr><tr><td>train/learning_rate</td><td>3e-05</td></tr><tr><td>train/loss</td><td>0.5226</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">robust-snowball-323</strong> at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/ob3u7vi7' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/ob3u7vi7</a><br> View project at: <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251105_015318-ob3u7vi7/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251105_015504-q1kmrqdr</code>
# Syncing run <strong><a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/q1kmrqdr' target="_blank">noble-river-324</a></strong> to <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface</a>
#  View run at <a href='https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/q1kmrqdr' target="_blank">https://wandb.ai/qltpagsuguiron-technological-institute-of-the-philippines/huggingface/runs/q1kmrqdr</a>
#     <div>
#
#       <progress value='132' max='660' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [132/660 01:46 < 07:11, 1.22 it/s, Epoch 1/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.443700</td>
#       <td>0.159560</td>
#       <td>0.955556</td>
#     </tr>
#   </tbody>
# </table><p>
# [I 2025-11-05 01:56:52,697] Trial 7 pruned.
# BestRun(run_id='0', objective=0.9911111111111112, hyperparameters={'learning_rate': 6.153875526724761e-05, 'per_device_train_batch_size': 16, 'weight_decay': 0.2763432701209472}, run_summary=None)

# %%
from pprint import pprint

# Write the best hyperparameters to a file
with open("hyperparameters.txt", "w") as f:
    for key, value in best_run.hyperparameters.items():
        f.write(f"{key}: {value}\n")

print("Best hyperparameters saved to hyperparameters.txt")
print("\nBest Hyperparameters:")
pprint(best_run.hyperparameters)
# Out:
# Best hyperparameters saved to hyperparameters.txt
#
# Best Hyperparameters:
# {'learning_rate': 6.153875526724761e-05,
#  'per_device_train_batch_size': 16,
#  'weight_decay': 0.2763432701209472}

# %% [markdown]
# # 🎯 Final Model Training
#
# Train with best hyperparameters and enhanced stability settings.
#
# **Core Settings**
# - Epochs: 10 (extended training)
# - Batch size (train): 64 | (eval): 16
# - Learning rate: Optuna-selected (6.43e-5) + cosine schedule + 10% warmup
# - Weight decay: 0.307
# - Label smoothing: 0.1 | Gradient clipping: 0.0
# - Dropout: attention / mlp / embedding / classifier = 0.0
#
# **Trainer Features**
# - `load_best_model_at_end` + accuracy selection
# - Epoch-level eval + checkpoint pruning (`save_total_limit=2`)
# - Weights & Biases tracking
# - Hub-ready (`hub_model_id` set)
#
# Outcome: `extended_final_model` directory containing the best fine‑tuned weights.

# %%
import shutil
import os

folder_path = "./results"
if os.path.exists(folder_path):
    shutil.rmtree(folder_path)
    print(f"Removed folder: {folder_path}")
else:
    print(f"Folder not found: {folder_path}")
# Out:
# Removed folder: ./results

# %%
# Use the ACTUAL best hyperparameters from Optuna optimization
from transformers import Trainer, TrainingArguments, AutoModelForSequenceClassification, DataCollatorWithPadding

model_id = "thomas-sounack/BioClinical-ModernBERT-base"

# Use the actual best hyperparameters from Optuna search
model = AutoModelForSequenceClassification.from_pretrained(
    model_id,
    num_labels=num_labels,
    label2id=label2id,
    id2label=id2label,
    attention_dropout=0.0,      # ✅ Correct parameter name
    mlp_dropout=0.0,             # ✅ Correct parameter name (not hidden_dropout)
    embedding_dropout=0.0,       # ✅ Optional but recommended
    classifier_dropout=0.0,      # ✅ Keep this
)

# Calculate training steps for warmup using optimal batch size
steps_per_epoch = len(tokenized_dataset["train"]) // best_run.hyperparameters["per_device_train_batch_size"]
total_steps = steps_per_epoch * 10
warmup_steps = int(total_steps * 0.1)

training_args = TrainingArguments(
    output_dir="./extended_final_model",

    # 🎯 OPTUNA-OPTIMIZED HYPERPARAMETERS
    per_device_train_batch_size=best_run.hyperparameters["per_device_train_batch_size"],  # 128 (from Optuna)
    learning_rate=best_run.hyperparameters["learning_rate"],                              # 4.76e-05 (from Optuna)
    weight_decay=best_run.hyperparameters["weight_decay"],                                # 0.258 (from Optuna)

    # 🚀 TRAINING CONFIGURATION
    per_device_eval_batch_size=16,          # Evaluation batch size
    num_train_epochs=8,                    # Extended training (doubled from 5)

    # 📈 OPTIMIZATION ENHANCEMENTS
    warmup_steps=warmup_steps,              # 10% of total steps for warmup
    lr_scheduler_type="cosine",             # Cosine learning rate decay
    label_smoothing_factor=0.1,             # Label smoothing for regularization
    max_grad_norm=1.0,                      # Gradient clipping for stability

    # 💾 CHECKPOINT & EVALUATION
    eval_strategy="epoch",                   # Evaluate every epoch
    save_strategy="epoch",                   # Save every epoch
    save_total_limit=2,                     # Keep only 2 best checkpoints
    load_best_model_at_end=True,            # Load best model after training
    metric_for_best_model="eval_accuracy",   # Use accuracy as selection metric
    greater_is_better=True,                 # Higher accuracy is better

    # 📊 LOGGING & TRACKING
    logging_strategy="epoch",                # Log every epoch
    report_to="wandb",                      # Report to Weights & Biases
    run_name="final_training_optimized_hyperparams",  # Updated run name

    # 🌐 HUGGING FACE INTEGRATION
    hub_model_id="rchrdwllm/BioClinical-ModernBERT-base-Symptom2Disease_WITHOUT-DROPOUT-42",

    # 🔧 REPRODUCIBILITY
    seed=42,                                # Fixed seed for reproducibility
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset['train'],
    eval_dataset=tokenized_dataset['validation'],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

# 🎯 START TRAINING
trainer.train()
# Out:
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='1056' max='1056' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1056/1056 17:19, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.959700</td>
#       <td>0.618974</td>
#       <td>0.935556</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.506300</td>
#       <td>0.491033</td>
#       <td>0.968889</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.455700</td>
#       <td>0.480813</td>
#       <td>0.971111</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.435400</td>
#       <td>0.458755</td>
#       <td>0.980000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.426300</td>
#       <td>0.462221</td>
#       <td>0.982222</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.421700</td>
#       <td>0.460659</td>
#       <td>0.982222</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.421400</td>
#       <td>0.460689</td>
#       <td>0.982222</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.421400</td>
#       <td>0.460636</td>
#       <td>0.982222</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1056, training_loss=0.5059963934349291, metrics={'train_runtime': 1040.2073, 'train_samples_per_second': 16.151, 'train_steps_per_second': 1.015, 'total_flos': 2225103949756800.0, 'train_loss': 0.5059963934349291, 'epoch': 8.0})

# %% [markdown]
# # 📈 Model Evaluation & Performance Analysis
#
# Assess generalization and practical usefulness.
#
# **Test Set**
# - Run final model on held‑out `test` split → accuracy + per‑class metrics.
#
# **Metrics**
# - Precision / Recall / F1 (macro & per class)
# - Confusion matrix for error patterns.
#
# **Cross‑Validation**
# - 5‑fold CV on training data reinitializing model per fold → average accuracy & variance.
#
# **Practical Checks**
# - Inference on handcrafted clinical symptom narratives.
# - Save artifacts (`final_model_train`) for deployment & reproducibility.
#
# Outcome: Quantitative metrics + qualitative sanity checks supporting reliability.

# %%
# Save the trained model and tokenizer explicitly
trainer.save_model("./final_model_train")
tokenizer.save_pretrained("./final_model_train")
# Out:
# ('./final_model_train/tokenizer_config.json',
#  './final_model_train/special_tokens_map.json',
#  './final_model_train/tokenizer.json')

# %%
from sklearn.metrics import classification_report
import numpy as np

test_split = tokenized_dataset["test"]
predictions, labels, metrics = trainer.predict(test_split)
y_pred = np.argmax(predictions, axis=1)
y_val = np.array(labels)

# Define target_names using the id2label dictionary
target_names = [id2label[i] for i in range(len(id2label))]

# Generate the classification report
print(classification_report(y_val, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Dengue       1.00      0.97      0.99        74
#     Diarrhea       1.00      1.00      1.00        65
#    Pneumonia       1.00      1.00      1.00        75
#    Influenza       0.97      0.94      0.95        79
#      Typhoid       0.99      1.00      0.99        73
#      Measles       0.93      0.98      0.95        84
#
#     accuracy                           0.98       450
#    macro avg       0.98      0.98      0.98       450
# weighted avg       0.98      0.98      0.98       450

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Get the true labels and predictions from the test set
test_split = tokenized_dataset["test"]
predictions, labels, _ = trainer.predict(test_split)
y_pred = np.argmax(predictions, axis=1)
y_true = np.array(labels)

# Generate the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Define labels for the confusion matrix
labels = [id2label[i] for i in range(num_labels)]

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.model_selection import StratifiedKFold
from transformers import Trainer, TrainingArguments, AutoModelForSequenceClassification
import numpy as np
from sklearn.metrics import classification_report, accuracy_score
import shutil
import os

# Define the number of folds
n_splits = 5
# Use StratifiedKFold to ensure balanced disease distribution in each fold
kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# Initialize lists to store evaluation results
all_accuracy_scores = []
all_classification_reports = []

# Convert the dataset to a pandas DataFrame for easier splitting
dataset_df = tokenized_dataset["train"].to_pandas()

# Get the labels for stratification
labels = dataset_df['labels']

for fold, (train_index, val_index) in enumerate(kf.split(dataset_df, labels)):
    folder_path = f"results_fold_{fold+1}"

    print("Removing previous cross val folder to save space...")

    if os.path.exists(folder_path):
        shutil.rmtree(folder_path)
        print(f"Removed folder: {folder_path}")
    else:
        print(f"Folder not found: {folder_path}")

    print(f"--- Fold {fold+1}/{n_splits} ---")

    # Create train and validation datasets for the current fold
    train_dataset_fold = tokenized_dataset["train"].select(train_index)
    val_dataset_fold = tokenized_dataset["train"].select(val_index)

    # Re-initialize the model for each fold to ensure a fresh start
    model = AutoModelForSequenceClassification.from_pretrained(
        model_id,
        num_labels=num_labels,
        label2id=label2id,
        id2label=id2label,
        attention_dropout=0.0,
        mlp_dropout=0.0,
        embedding_dropout=0.0,
        classifier_dropout=0.0,
    )

    # Define training arguments for the current fold
    # Using the best hyperparameters found in the hyperparameter search
    training_args_fold = TrainingArguments(
        output_dir=f"./results_fold_{fold+1}",
        learning_rate=best_run.hyperparameters["learning_rate"],
        per_device_train_batch_size=best_run.hyperparameters["per_device_train_batch_size"],
        weight_decay=best_run.hyperparameters["weight_decay"],

        # Match final training configuration:
        num_train_epochs=8,  # Instead of 5
        warmup_steps=int((len(train_dataset_fold) // best_run.hyperparameters["per_device_train_batch_size"]) * 10 * 0.1),
        lr_scheduler_type="cosine",
        label_smoothing_factor=0.1,
        max_grad_norm=1.0,

        eval_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True,
        logging_strategy="epoch",
        report_to="none",
    )

    # Create Trainer for the current fold
    trainer_fold = Trainer(
        model=model,
        args=training_args_fold,
        train_dataset=train_dataset_fold,
        eval_dataset=val_dataset_fold,
        compute_metrics=lambda eval_pred: {"accuracy": (eval_pred.predictions.argmax(-1) == eval_pred.label_ids).mean()},
        data_collator=data_collator,
    )

    # Train the model for the current fold
    trainer_fold.train()

    # Evaluate the model on the validation data for the current fold
    predictions, labels, metrics = trainer_fold.predict(val_dataset_fold)
    y_pred_fold = np.argmax(predictions, axis=1)
    y_val_fold = np.array(labels)

    # Calculate and store accuracy and classification report
    accuracy_fold = accuracy_score(y_val_fold, y_pred_fold)
    report_fold = classification_report(y_val_fold, y_pred_fold, target_names=[id2label[i] for i in range(num_labels)])

    all_accuracy_scores.append(accuracy_fold)
    all_classification_reports.append(report_fold)

    print(f"Accuracy for Fold {fold+1}: {accuracy_fold}")
    print(f"Classification Report for Fold {fold+1}:\n{report_fold}")

# Print average accuracy across all folds
print("\n--- Overall Results ---")
print(f"Average Accuracy across {n_splits} folds: {np.mean(all_accuracy_scores)}")

# Optionally, print classification reports for each fold
print("\n--- Classification Reports for Each Fold ---")
for fold, report in enumerate(all_classification_reports):
    print(f"Classification Report for Fold {fold+1}:\n{report}")
# Out:
# Removing previous cross val folder to save space...
# Folder not found: results_fold_1
# --- Fold 1/5 ---
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='840' max='840' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [840/840 16:11, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.090100</td>
#       <td>0.625252</td>
#       <td>0.945238</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.515900</td>
#       <td>0.490753</td>
#       <td>0.976190</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.448800</td>
#       <td>0.474338</td>
#       <td>0.978571</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.429100</td>
#       <td>0.466353</td>
#       <td>0.983333</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.424100</td>
#       <td>0.464009</td>
#       <td>0.976190</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.422000</td>
#       <td>0.461505</td>
#       <td>0.980952</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.421600</td>
#       <td>0.461580</td>
#       <td>0.983333</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.421600</td>
#       <td>0.461627</td>
#       <td>0.980952</td>
#     </tr>
#   </tbody>
# </table><p>
# Accuracy for Fold 1: 0.9809523809523809
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#       Dengue       0.99      0.96      0.97        72
#     Diarrhea       1.00      1.00      1.00        72
#    Pneumonia       0.97      1.00      0.99        69
#    Influenza       0.93      1.00      0.97        69
#      Typhoid       1.00      0.96      0.98        68
#      Measles       1.00      0.97      0.99        70
#
#     accuracy                           0.98       420
#    macro avg       0.98      0.98      0.98       420
# weighted avg       0.98      0.98      0.98       420
#
# Removing previous cross val folder to save space...
# Folder not found: results_fold_2
# --- Fold 2/5 ---
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='840' max='840' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [840/840 17:22, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.962000</td>
#       <td>0.603290</td>
#       <td>0.942857</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.523000</td>
#       <td>0.503370</td>
#       <td>0.971429</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.455500</td>
#       <td>0.475206</td>
#       <td>0.976190</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.429900</td>
#       <td>0.467603</td>
#       <td>0.983333</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.425800</td>
#       <td>0.462955</td>
#       <td>0.978571</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.422100</td>
#       <td>0.466679</td>
#       <td>0.973810</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.421600</td>
#       <td>0.467240</td>
#       <td>0.976190</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.421500</td>
#       <td>0.467414</td>
#       <td>0.976190</td>
#     </tr>
#   </tbody>
# </table><p>
# Accuracy for Fold 2: 0.9785714285714285
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#       Dengue       0.99      1.00      0.99        71
#     Diarrhea       1.00      0.99      0.99        73
#    Pneumonia       0.99      1.00      0.99        69
#    Influenza       0.96      0.97      0.96        69
#      Typhoid       0.98      0.96      0.97        68
#      Measles       0.96      0.96      0.96        70
#
#     accuracy                           0.98       420
#    macro avg       0.98      0.98      0.98       420
# weighted avg       0.98      0.98      0.98       420
#
# Removing previous cross val folder to save space...
# Folder not found: results_fold_3
# --- Fold 3/5 ---
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='840' max='840' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [840/840 17:06, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.981300</td>
#       <td>0.612518</td>
#       <td>0.940476</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.506400</td>
#       <td>0.532045</td>
#       <td>0.945238</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.453200</td>
#       <td>0.503815</td>
#       <td>0.966667</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.429400</td>
#       <td>0.508569</td>
#       <td>0.954762</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.424800</td>
#       <td>0.507604</td>
#       <td>0.961905</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.422000</td>
#       <td>0.506664</td>
#       <td>0.959524</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.421600</td>
#       <td>0.506652</td>
#       <td>0.959524</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.421600</td>
#       <td>0.506671</td>
#       <td>0.959524</td>
#     </tr>
#   </tbody>
# </table><p>
# Accuracy for Fold 3: 0.9666666666666667
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#       Dengue       0.95      1.00      0.97        71
#     Diarrhea       0.99      1.00      0.99        73
#    Pneumonia       0.99      1.00      0.99        68
#    Influenza       0.98      0.90      0.94        70
#      Typhoid       1.00      0.96      0.98        69
#      Measles       0.90      0.94      0.92        69
#
#     accuracy                           0.97       420
#    macro avg       0.97      0.97      0.97       420
# weighted avg       0.97      0.97      0.97       420
#
# Removing previous cross val folder to save space...
# Folder not found: results_fold_4
# --- Fold 4/5 ---
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='840' max='840' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [840/840 17:23, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.986200</td>
#       <td>0.597549</td>
#       <td>0.950000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.518500</td>
#       <td>0.511068</td>
#       <td>0.959524</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.454800</td>
#       <td>0.479902</td>
#       <td>0.969048</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.436900</td>
#       <td>0.479027</td>
#       <td>0.971429</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.427000</td>
#       <td>0.484902</td>
#       <td>0.971429</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.422900</td>
#       <td>0.485046</td>
#       <td>0.966667</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.421800</td>
#       <td>0.483659</td>
#       <td>0.969048</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.421600</td>
#       <td>0.483790</td>
#       <td>0.966667</td>
#     </tr>
#   </tbody>
# </table><p>
# Accuracy for Fold 4: 0.9714285714285714
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#       Dengue       1.00      0.97      0.99        71
#     Diarrhea       0.99      1.00      0.99        72
#    Pneumonia       1.00      1.00      1.00        69
#    Influenza       0.97      0.91      0.94        70
#      Typhoid       0.99      0.97      0.98        69
#      Measles       0.89      0.97      0.93        69
#
#     accuracy                           0.97       420
#    macro avg       0.97      0.97      0.97       420
# weighted avg       0.97      0.97      0.97       420
#
# Removing previous cross val folder to save space...
# Folder not found: results_fold_5
# --- Fold 5/5 ---
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at thomas-sounack/BioClinical-ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='840' max='840' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [840/840 16:20, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.983100</td>
#       <td>0.601579</td>
#       <td>0.930952</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.520300</td>
#       <td>0.512122</td>
#       <td>0.976190</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.462100</td>
#       <td>0.463417</td>
#       <td>0.988095</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.436700</td>
#       <td>0.478922</td>
#       <td>0.978571</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.426800</td>
#       <td>0.466065</td>
#       <td>0.985714</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.422300</td>
#       <td>0.463622</td>
#       <td>0.985714</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.421800</td>
#       <td>0.467605</td>
#       <td>0.980952</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.421600</td>
#       <td>0.467529</td>
#       <td>0.980952</td>
#     </tr>
#   </tbody>
# </table><p>
# Accuracy for Fold 5: 0.9880952380952381
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#       Dengue       0.99      1.00      0.99        71
#     Diarrhea       1.00      1.00      1.00        72
#    Pneumonia       1.00      1.00      1.00        69
#    Influenza       0.99      0.96      0.97        70
#      Typhoid       1.00      0.99      0.99        69
#      Measles       0.96      0.99      0.97        69
#
#     accuracy                           0.99       420
#    macro avg       0.99      0.99      0.99       420
# weighted avg       0.99      0.99      0.99       420
#
#
# --- Overall Results ---
# Average Accuracy across 5 folds: 0.9771428571428572
#
# --- Classification Reports for Each Fold ---
# Classification Report for Fold 1:
#               precision    recall  f1-score   support
#
#       Dengue       0.99      0.96      0.97        72
#     Diarrhea       1.00      1.00      1.00        72
#    Pneumonia       0.97      1.00      0.99        69
#    Influenza       0.93      1.00      0.97        69
#      Typhoid       1.00      0.96      0.98        68
#      Measles       1.00      0.97      0.99        70
#
#     accuracy                           0.98       420
#    macro avg       0.98      0.98      0.98       420
# weighted avg       0.98      0.98      0.98       420
#
# Classification Report for Fold 2:
#               precision    recall  f1-score   support
#
#       Dengue       0.99      1.00      0.99        71
#     Diarrhea       1.00      0.99      0.99        73
#    Pneumonia       0.99      1.00      0.99        69
#    Influenza       0.96      0.97      0.96        69
#      Typhoid       0.98      0.96      0.97        68
#      Measles       0.96      0.96      0.96        70
#
#     accuracy                           0.98       420
#    macro avg       0.98      0.98      0.98       420
# weighted avg       0.98      0.98      0.98       420
#
# Classification Report for Fold 3:
#               precision    recall  f1-score   support
#
#       Dengue       0.95      1.00      0.97        71
#     Diarrhea       0.99      1.00      0.99        73
#    Pneumonia       0.99      1.00      0.99        68
#    Influenza       0.98      0.90      0.94        70
#      Typhoid       1.00      0.96      0.98        69
#      Measles       0.90      0.94      0.92        69
#
#     accuracy                           0.97       420
#    macro avg       0.97      0.97      0.97       420
# weighted avg       0.97      0.97      0.97       420
#
# Classification Report for Fold 4:
#               precision    recall  f1-score   support
#
#       Dengue       1.00      0.97      0.99        71
#     Diarrhea       0.99      1.00      0.99        72
#    Pneumonia       1.00      1.00      1.00        69
#    Influenza       0.97      0.91      0.94        70
#      Typhoid       0.99      0.97      0.98        69
#      Measles       0.89      0.97      0.93        69
#
#     accuracy                           0.97       420
#    macro avg       0.97      0.97      0.97       420
# weighted avg       0.97      0.97      0.97       420
#
# Classification Report for Fold 5:
#               precision    recall  f1-score   support
#
#       Dengue       0.99      1.00      0.99        71
#     Diarrhea       1.00      1.00      1.00        72
#    Pneumonia       1.00      1.00      1.00        69
#    Influenza       0.99      0.96      0.97        70
#      Typhoid       1.00      0.99      0.99        69
#      Measles       0.96      0.99      0.97        69
#
#     accuracy                           0.99       420
#    macro avg       0.99      0.99      0.99       420
# weighted avg       0.99      0.99      0.99       420

# %%
from transformers import pipeline

classifier = pipeline(
    task="text-classification",
    model="./final_model_train", # Use the fine-tuned model instead of model_id
    tokenizer=tokenizer, # Add the tokenizer
    device=0,
)

# Prompted from ChatGPT to simulate kunwari yung symptoms dedescribe niya ganon
dengue_sample ="I've been hit with a sudden, very high fever that came on a few days ago, and it's making me feel absolutely miserable. I have a throbbing headache that just won't quit, and my eyes hurt, especially behind them. My muscles and joints ache so intensely it feels like my bones are breaking. I'm utterly exhausted, sometimes feel nauseous, and have even thrown up once or twice. To top it all off, I've noticed a red, spotty rash spreading across my skin, and sometimes my gums bleed a little when I brush my teeth."
influenza_sample = "I woke up feeling like a truck hit me. It started with a sudden fever and chills, and now I'm aching all over my body – my muscles, my head, everywhere. I have a terrible dry cough that won't stop, and my throat is really sore. I feel so run down and tired that I can barely get out of bed, and I've completely lost my appetite. I'm also experiencing a lot of congestion and a runny nose, and sometimes I feel a bit dizzy."
typhoid_sample = "I've been dealing with a persistent and gradually worsening fever for about two weeks now, which has left me completely exhausted. It started subtle but has been getting higher each day. I have a constant headache, and my abdomen feels uncomfortably full and painful, sometimes I even get cramps. I'm either constipated or having mild diarrhea. I barely want to eat anything, and I've lost weight. I also feel a bit confused and just generally unwell, like I'm in a haze."
pneumonia_sample = "I've had a really bad cough for over a week now, and it's getting worse, bringing up a lot of thick, yellowish-green mucus. I keep getting high fevers accompanied by severe chills, and I'm sweating through my clothes, especially at night. It's become incredibly difficult to breathe, and I feel constantly short of breath, even when I'm just sitting still. Every time I try to cough or take a deep breath, I get a sharp, stabbing pain in my chest. I'm so weak and fatigued all the time, my appetite is gone, and lately, I've been feeling confused and lightheaded, which is really worrying me."
diarrhea_sample = "For the past day or two, I've had severe, watery diarrhea, and I'm having to run to the bathroom constantly. My stomach is cramping intensely, and I'm experiencing a lot of bloating and gas. I also feel quite nauseous and have vomited a few times. I'm starting to feel really weak and dizzy from losing so many fluids, and I have a dry mouth. I'm worried because the abdominal pain is quite severe, and I haven't been able to keep much food or water down."
measles_sample = "It started a few days ago with a fever, runny nose, sore throat, and a really irritating cough, almost like a bad cold. My eyes are red, watery, and very sensitive to light. Then, about a day or two ago, I noticed tiny white spots, like grains of salt, inside my mouth. Today, a red, blotchy rash appeared on my face, starting near my hairline, and it's now spreading down my neck and body. I feel really unwell and lethargic."

result_1 = classifier(dengue_sample)
result_2 = classifier(pneumonia_sample)
result_3 = classifier(typhoid_sample)
result_4 = classifier(influenza_sample)
result_5 = classifier(measles_sample)
result_6 = classifier(diarrhea_sample)

result_1, result_2, result_3, result_4, result_5, result_6
# Out:
# Device set to use cuda:0
# ([{'label': 'Dengue', 'score': 0.9018368124961853}],
#  [{'label': 'Pneumonia', 'score': 0.9063116908073425}],
#  [{'label': 'Typhoid', 'score': 0.8395552635192871}],
#  [{'label': 'Influenza', 'score': 0.9134637713432312}],
#  [{'label': 'Measles', 'score': 0.9075693488121033}],
#  [{'label': 'Diarrhea', 'score': 0.9163240790367126}])

# %%
import shutil

# Download the model
shutil.make_archive("BioClinical_ModernBERT_base_Symptom2Disease_dataset_WITH-DROPOUT", 'zip', "final_model_train")
# Out:
# '/content/BioClinical_ModernBERT_base_Symptom2Disease_dataset_WITH-DROPOUT.zip'

# %% [markdown]
# # 🔬 Overfitting & Data Integrity Checks
#
# High accuracy can signal either strong generalization or issues (data leakage, overlap, artifacts). This section validates correctness.
#
# **Risks Investigated**
# - Data leakage (same text in multiple splits)
# - Memorization / overfitting
# - Spurious artifacts (format, boilerplate)
#
# **Checks**
# 1. Text overlap detection between train / validation / test.
# 2. Full test sweep: predicted vs expected labels (spot anomalies).
# 3. Qualitative inspection of difficult / long samples.
#
# **Interpretation Guide**
# - Zero / near‑zero overlap → split integrity OK.
# - Consistently confident & correct predictions → likely real signal; verify class balance.
# - If suspicious, consider: stratified splits, adding noise tests, or external validation set.
#
# Outcome: Evidence that performance reflects genuine learning (or flags to address).

# %%
for row in dataset['test']:
  result = classifier(row['text'])

  print(f"Row text: {row['text']}")
  print(f"Expected: {id2label[row['labels']]}")
  print(f"Predicted: {result[0]['label']}\n")
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Row text: Symptoms exploded within hours starting early yesterday with profound muscle aches and exhaustion. Dry cough keeping me awake, scratchy painful throat, fever measured at 102.6Â°F this afternoon, and body feels completely drained. Leg and shoulder muscles extremely sore. No runny nose paired with red eyes and cough simultaneously.
# Expected: Measles
# Predicted: Measles
#
# Row text: It came on so suddenly while I was out shopping on Saturday. My temperature shot up to 102.8°F, and I was hit with such severe pain in my legs and back that I couldn't walk without help. I'm dealing with extreme fatigue, forcing me to rest every hour. A dry, hacking cough started up after the fever hit. Even in a heated car, I had violent chills. It also hurts a little to swallow because of a mild sore throat, and my frontal headache gets worse if I move my head. I had to leave my cart and get out of the store, which is crazy because just hours before I was feeling energetic and browsing with no problems.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: I'm on day three of a sudden high fever, chills, and aches that feel deep in my bones. I'm exhausted and have developed a nagging dry cough. My main issue is the sudden, severe muscle pain, not a prolonged fever that's been building for a week.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: For the last three days, a 103.0°F fever has been accompanied by a severe headache. My joints are aching with great intensity, especially my hips. I'm also experiencing a noticeable pain behind my eyes, and yesterday a faint rash appeared on my arms.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: My condition worsened acutely, with my temperature now at 103.8°F. There's a severe, generalized muscle pain that feels most intense in my shoulders and thighs. The exhaustion is so debilitating it forces me to stay in a horizontal position. I'm also having intense chilling episodes and a harsh, non-productive cough, leaving me totally immobilized.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: Over the last three days, I've been having about four loose stools daily. The cramping in my stomach has been mild. I don't feel too sick, just a bit fatigued. I haven't had a fever or noticed any signs of being dehydrated. It's really just been an inconvenience more than anything.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: This morning on my way to work I was completely fine, but everything changed around lunchtime. A fever of 102.2°F came on, and with it, severe muscle soreness everywhere. I'm also dealing with a persistent dry cough and a noticeable headache. The exhaustion is so extreme that I've been confined to my bed ever since.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: It started with a temperature of 100°F eight days ago, which had escalated to 103.5°F by the sixth day. I have a severe, unceasing headache that feels like constant pressure across my forehead. My lower belly is tender and I've been having cramps, particularly on the right side. I'm so weak that just getting to the bathroom is a major effort. I haven't wanted to eat for days; the thought of it makes me nauseous. For the first four days I was constipated, but now I'm experiencing loose, watery stools.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: A couple of days ago, I started with constant diarrhea, and today I've already had seven loose bowel movements. The stomach cramps are intense, and they seem to come and go in waves, creating a sudden and urgent need to find a bathroom. My thirst is unceasing, and my lips are very dry. Along with feeling weak, I've been running a slight fever of 100.2°F.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: A significant high fever of 103.1°F has been persisting for 48 hours. I have pronounced shortness of breath with chills and body soreness. A persistent, productive cough is bringing up greenish sputum, and I have a sharp, knife-like pleuritic pain. This is all incredibly uncomfortable.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: High fever for four days now that goes up and down, reaching 104.2Â°F. Excruciating pain in my joints and muscles, severe headache behind my eyes, and throwing up twice today. Noticed some tiny broken blood vessels on my lower legs. No face-first rash spreading downward or sensitivity to light with persistent fever.
# Expected: Measles
# Predicted: Measles
#
# Row text: I have been feeling unwell for more than a week, with a steady fever that doesn't seem to break. My head hurts constantly, and I have zero energy. I've also had some stomach cramps. I'm sure I don't have the three symptoms of cough, runny nose, and red watery eyes.
# Expected: Measles
# Predicted: Measles
#
# Row text: I've been completely immobile for seven days now with a 105.0°F fever. The pain behind my eyes makes even the slightest eyelid movement excruciating, and it feels like every joint, especially my hips, has been pulverized. When I vomited this morning, it was bright red blood. My skin is now covered in mottled purple lesions from my neck to my feet that don't go away when pressed.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: I have been sick for over a week with a fever that doesn't go away, a headache, and a very poor appetite. I feel so tired I can barely function. My stomach has been bothering me as well. I do not have the combination of cough, runny nose, and red eyes.
# Expected: Influenza
# Predicted: Measles
#
# Row text: Since yesterday morning, a fever of 101.7°F and shaking chills have set in. I have a persistent, productive cough that expels deep green phlegm. An agonizing pain is fixed in my upper right chest, and it becomes much more intense when I breathe or cough. My shortness of breath is severe, and I'm too exhausted to perform my daily tasks. This sickness is definitely getting worse, and my fever isn't responding to medication.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: Three days ago, I began feeling like I was burning up with a fever of 102.8°F. My cough is productive, and I'm bringing up rusty-colored secretions. I have a sharp, agonizing pain in the center of my chest that is set off by any movement related to breathing. My breathing is compromised, my body feels like lead, and I have chills that won't go away. It is a struggle to take every breath.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: My fever has been moving up for five days, from 99.5°F to 101.8°F. In all that time, I haven't really eaten anything substantial. My forehead is just pounding with pain. I've been completely unable to have a bowel movement for three days. All of my energy is just gone.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: For the past six days, I've had a consistent temperature of 104.8°F. The pain behind my eyes is so sharp that I can't fully open them. Any movement in bed causes all of my joints to ache intensely. This afternoon, I experienced a significant nosebleed that saturated two tissues, and I've noticed red patches on my feet.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: Over the past four days, my temperature has been elevated at 102.4°F. I have a pounding headache and a significant amount of pain behind my eyes. My joints are causing me a lot of soreness, and I just noticed a light rash on my arms when I woke up today.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: I'm just stuck in bed, can't move at all because I'm so weak. This has been going on for eleven days with a fever that just keeps climbing, from 100°F to 104.3°F. My forehead hurts so bad and it never stops. My lower right belly is super sore when you touch it. I can't eat anything. Since day nine, I've had these little pink spots on my stomach. My heart is also beating slow, which feels weird with such a high fever.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: For two days, I have had a 101.0°F fever and a mild headache. My joints feel somewhat stiff, and I have a low-grade, non-productive cough. I feel quite worn out, and my appetite has decreased.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: For precisely 60 hours, I've had a 100.8°F fever and a dull pressure in my head. My finger joints make a painful clicking sound when I try to type, and I've noticed the area behind my eyes is sensitive to sunlight. This morning, I found three clear red marks on my left forearm that resemble tiny bruises, though they are not sore or itchy.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: Five days ago, a very high fever of 104.8°F began, accompanied by a severe, hacking dry cough, a large amount of clear nasal discharge, and severe conjunctivitis. The light sensitivity is extreme—even dim light is painful for my eyes. A widespread red rash that began behind my ears now covers my entire face, neck, and chest, and is rapidly advancing to my abdomen.
# Expected: Measles
# Predicted: Measles
#
# Row text: It's been 11 days since my fever began at 100.8°F, and it has remained persistently high, currently at 104.5°F. The headache at the front of my head is unbearable, and my stomach is severely tender to the touch. Due to extreme weakness, I have been completely unable to leave my bed. I haven't been able to eat anything for days. Since the seventh day, I've been experiencing loose stools. I've also noticed that my pulse seems unusually slow for such a high fever.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: It all came on at once: a sudden 102.4°F fever, severe body aches, and extreme fatigue. I've also got chills, a headache, and a persistent dry cough. The most defining part is how sudden it was—one moment I was fine, and the next I was incredibly sick.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: I've been running a fever for 10 days, which began at 101.2°F and has been holding at 103.6°F. The headache across my forehead is constant and severe. There is a considerable amount of pain in my lower abdomen. I feel utterly exhausted and have no appetite whatsoever. Two days ago, I started noticing small pink spots on my abdomen.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: The illness started just yesterday. I went from feeling okay to having a 102.5Â°F fever and horrible muscle pains in just a few hours. I feel completely wiped out and have a slight headache. I have no abdominal pain or any kind of rash.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: Since Thursday, I've had a persistent fever of around 101.1°F, accompanied by a constant pressure between my temples. My hip joints feel like they lock up whenever I stand, and I have a strange, deep ache behind my eyes when I blink. My appetite completely disappeared yesterday, even though I don't feel nauseous, and I found three distinct red marks on my left calf while showering.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: Over the past five days, my temperature has stayed around 104.2°F. The pain behind my eyes is really intense, and my joints hurt so much that it's become difficult to get around. I've also noticed blood in my saliva from time to time since yesterday.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: For a couple of days now, my stools have been watery, and I'm going about six times a day. The cramping isn't severe, but it's annoying and mild. I've been feeling thirsty and have a dry mouth, which has made me drink more water. I just feel a bit off, and I have a slight fever of 99.5°F.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: It’s been 32 hours since this hit me during a movie on Monday evening. I suddenly collapsed, which was a stark contrast to that afternoon when I was cooking dinner. My temperature is 103.8°F, and I have rigors that are strong enough to shake the bed frame. The myalgia in my entire back is unbearable and prevents me from changing positions. I have extreme exhaustion that keeps me from speaking any louder than a whisper, and a single bout of my dry cough is completely draining. I am now at the point of total dependence for hydration.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: About five hours ago, this all started. I felt perfectly fine this morning while I was out gardening, but by lunchtime, everything had changed. A sudden 101.3°F fever began, along with moderate aches spreading through my shoulders and thighs. The dry tickle that was in my throat has become persistent coughing fits. I'm also getting intermittent chills when my fever is at its highest, plus there's a mild pressure in the front of my head. The unusual fatigue made it impossible to continue my desk work, and despite resting, the symptoms are still here. In three hours, I went from normal to being unable to do my planned tasks or even make food for myself.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: A sudden high fever started about 48 hours ago, and the body aches are unbearable, it feels like my bones are breaking. The pain is worst behind my eyes. I feel nauseous but haven't thrown up. I definitely don't have any pinkish spots on my belly or chest.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: Since yesterday, my fever has been climbing and is now at 103.9°F. The worst part is a severe, building pressure behind my eyes that gets worse if I move them. My knees and elbows are in so much pain that I can hardly straighten my arms or legs, and I've just spotted a faint rash starting on my lower legs.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: I'm getting worse every day. It's been 7 days, and my temperature just keeps climbing, from 100.5°F to 102.9°F now. I'm too weak to do my daily tasks. My lower belly is really sensitive, and my forehead has a constant, dull ache. I have no appetite at all, and I haven't been able to poop since this started.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: Since last night, I've had 7 large-volume, very watery bowel movements. I'm dealing with significant stomach cramps and a persistent feeling of nausea. Despite drinking a lot of water, I feel weak and very thirsty. I do not have a fever.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: This started three days ago, and my temperature has been climbing to 101.3°F. A cough that produces pale yellow material just won't stop. Each breath I take causes a knife-like sensation in the center of my chest, and I feel like I am gasping for air. I'm experiencing weakness and fever with teeth-chattering chills, and I'm feeling increasingly unwell as this condition worsens.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: Been sick for a whole week now. My brain isn't working right, I couldn't even remember my PIN code twice today. The fever went from 100.3°F to 102.9°F. The pain in the front of my head is splitting my skull. My belly hurts with even a light touch. I'm too tired for phone calls and can only sip broth. I haven't had a bowel movement since Thursday.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: It's been thirteen days of being sick, and my fever has been on a wild ride, going from 99.5 all the way up to 104.8. My forehead feels like it's being constantly hammered, and the pain in my lower gut is so bad I can't even lie on that side. I'm completely stuck in bed, just too weak to do anything. For more than a week, I haven't wanted to eat at all. Since the eleventh day, I've had these salmon-colored spots on my stomach. My thoughts are all jumbled; I'm getting family members' names wrong and can't recall simple things. The area around my liver is also feeling swollen and sore.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: I feel like I'm suffocating between coughs. My fever has been stuck at 103.0°F despite medicine. This cough is persistent and I'm spitting up dark green gunk. My left lung area hurts with an intense pain when I try to take a deep breath. I have never felt anything like this.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: I've had about six loose, greenish stools throughout today. The abdominal pain is moderate, and I feel a constant urge to use the restroom. I've been making an effort to drink water because my lips are dry and I feel thirsty. I also feel a bit nauseous and generally unwell, but I do not have a fever.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: My fever has been ongoing for ten days now, starting at 100°F and reaching 103.8°F today. I have a severe, persistent headache across my forehead. There's significant pain and tenderness in the lower part of my stomach. I'm incredibly weak and mostly stuck in bed. I can't keep any food down, and my appetite is completely gone. I was constipated during the first week, but now I'm experiencing diarrhea. A small pink rash appeared on my belly yesterday.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: For the past five days, I've been running a 104.1°F fever and have had the "3 Cs." Light has been bothering my eyes significantly. A red rash with both flat and bumpy spots started on my face two days ago; it has since worked its way down to my torso and is now beginning to show up on my arms. Throughout the time the rash has been present, my fever has not gone down.
# Expected: Measles
# Predicted: Measles
#
# Row text: I've been running a 102.5°F fever for three days now. Along with the fever, I'm dealing with a significant headache and a bad pain behind my eyes. My back and legs are aching deeply. Since this morning, I've also been feeling very nauseous.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: This whole thing came on suddenly three days ago with a fever of 102.4°F. My temperature has been up and down, but the one thing that's gotten consistently worse is the constant pressure behind my eyes. My joints, particularly in my hips and shoulders, hurt every time I try to move, and I'm feeling more and more wiped out even though I haven't been doing much.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: Since Friday, I've had a fever of 100.9°F, and my eyes feel like they are permanently full of sand. When I type emails, my thumbs and index fingers make a painful clicking sound. This afternoon, I found three separate, pinprick-like red marks on my left forearm. While I haven't thrown up, I have this constant nausea that has completely taken away my appetite.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: An 11-day high fever that started at 101.3°F is now at 104.1°F. The headache at the front of my head is intense, and my lower stomach area is in extreme pain. I'm so exhausted I can't do anything, and I have zero desire to eat. Small pink spots began to show up on my chest around day nine.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: I can't even stand up properly, I'm just so weak. The fever has been around for ten days, climbing from 100.5°F to 104°F. My forehead has this constant, bad headache. My lower belly area hurts a lot and is really tender. My appetite is completely gone. There's also a pink rash on my chest and stomach that started in the second week. Sometimes my thoughts get all jumbled and I don't think clearly.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: Ten full days of this fever nightmare. 101.3°F at the start, now 104.1°F. The headache in my forehead never stops, it's torture. My lower belly hurts so much, super tender to touch. Can't leave bed, way too weak. Food makes me want to throw up just thinking about it. My heartbeat feels weird and slow considering how high my temp is.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: A fever started 13 days ago, rising from 101.5°F to a high of 104.5°F. I'm dealing with a severe, non-stop headache in the front of my head and intense pain in my lower abdomen. I am completely worn out, can hardly move, and have no interest in food. Around the tenth day, small pink spots emerged on my abdomen. I've also noticed that my pulse seems slower than usual.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: This started Wednesday when I woke up with bone-rattling chills. My temperature is 103.9°F, and the pain in my neck and quadriceps is excruciating; I need assistance just to turn my head. I have a dry cough that exhausts me after a single episode, and I'm dealing with extreme fatigue that makes basic hygiene impossible. A moderate frontal headache pulses with my heartbeat. It's a shocking contrast to attending the theater on Tuesday evening. Now, 31 hours later, I'm in total prostration with a high fever that won't respond to aggressive antipyretics, requiring catheterization and continuous care for all my needs, including hydration and positioning.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: Waking up this morning, I felt like a bus had hit me. My body aches, I have a splitting headache, and my temperature is 102°F. On top of that, my throat is sore and I have a cough. The sense of fatigue is just overwhelming. I have not had any bleeding from my gums.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: I've had three loose bowel movements since a mild case of diarrhea began last night. The cramps in my abdomen are barely noticeable. I feel a little off, but I don't have a temperature, nor am I feeling weak or thirsty. The situation feels very much under control.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: This came on without any warning after my morning walk on Sunday. I was fine at breakfast, but by noon I had a 101.4°F fever and mild aches all over. I'm noticeably fatigued, enough that I'm stuck on the couch and had to put off doing laundry. I also have an occasional dry cough, a bit of rawness in my throat, and some minimal pressure in my forehead, but I haven't had any chills or nasal congestion.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: For five days, I have been dealing with a very high 104.5°F fever, a severe hacking cough, a large amount of clear fluid from my nose, and intensely red, watery eyes. Light is so painful I can't stand it. Two days ago, I noticed small white spots that look like salt grains inside my cheeks. A widespread red rash began behind my ears and has now completely covered my face, neck, and chest, and is quickly moving down my abdomen.
# Expected: Measles
# Predicted: Measles
#
# Row text: A 102.4°F fever and shaking chills have been going on for six days now. I have a constant, productive cough that brings up deep green phlegm. A considerable sharp pain is located in the center of my chest and gets worse with breathing and coughing. My breathing is labored, and the profound fatigue is preventing me from doing my usual tasks. The fever isn't breaking with medication, and I feel my condition worsening and the symptoms progressing.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: Over the last 24 hours, I have had 14 bowel movements. They are watery in consistency and contain both blood and mucus. The cramping is severe and does not let up. I feel extremely weak and dizzy, and my mouth is parched. I haven't been able to urinate for several hours. I'm running a high fever of 103°F and have also been vomiting.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: This hit me hard on Friday during my drive home. I developed a 102.6°F fever and severe pain in my arms and back, so bad that I need help to the bathroom. My weakness is profound, forcing me to rest every hour. A dry, hacking cough appeared around 6 PM, and I have moderate chills that persisted even with the car's heat on. A mild headache is sitting behind my eyes. I haven't managed to check my work emails at all, which is a total flip from this morning when I felt sharp on my way to the office.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: A 102.5°F fever came on suddenly three days ago. It brought a splitting headache and aches all over my body, especially in my muscles. I get a sharp pain behind my eyes when I move them. I have also been feeling quite nauseous and had one minor nosebleed.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: A cough started a few days ago and now it's very productive. I have a fever and it hurts to breathe in. I feel like I can't get enough air. I do not have a runny nose or red, watery eyes accompanying my cough.
# Expected: Influenza
# Predicted: Measles
#
# Row text: For the past five days with this 103.4°F fever, I've had a constant stabbing pain behind my eyes that is bad enough to wake me up from sleep. By the time evening comes around, my knuckles are painfully swollen. I also had a nosebleed yesterday that took twenty minutes of pinching my nose to finally stop. Today, I've noticed tiny red dots appearing on my forearms and chest.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: This started last night with an urgent need to go to the toilet, and I've had watery diarrhea about 6 times since then. I'm also having some cramping. I don't have a cough, and I checked for any white spots in my mouth and there are none.
# Expected: Measles
# Predicted: Influenza
#
# Row text: I've been dealing with a mild illness for the past four days, which includes a 102.1°F fever, a nagging dry cough, and a runny nose. I've been managing to get some rest. My eyes are red and only a little sensitive to light; it's not severe. A faint, blotchy rash started at my hairline today and is now slowly moving down my face.
# Expected: Measles
# Predicted: Measles
#
# Row text: My fever is 103.7°F, and I feel severe musculoskeletal discomfort everywhere, along with severe generalized cranial pain. The shivering is so violent that being bundled up provides no relief, and I have an irritating dry cough. I declined so rapidly that I need a caregiver present constantly. This is a medical emergency; my severity is escalating, the symptoms persist, and I need comprehensive care.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: I'm exhausted. It's been 4 days of this 102.7°F fever. My muscles are all aching and I can't catch my breath. My cough brings up this rusty-looking gunk. There is a sharp pain in my left chest that feels worse when I breathe.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: This just came out of nowhere. I woke up this morning with a 103.8°F fever, feeling like a bus had run me over. The muscle pain is excruciating, leaving me completely prostrated and unable to function at all. I'm also experiencing violent chills and have a deep, non-productive cough.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: This has been going on for three days now. Today, I've had seven loose, foul-smelling stools. The cramping is of moderate intensity. Despite trying to drink plenty of fluids, I still feel thirsty and have a dry mouth. I am running a slight fever of 99.6°F. I feel weak, generally unwell, and experience a sudden urge to go each time.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: Today, I've had seven loose stools that contained some visible blood and mucus. The cramping is severe, and the urgency is a major issue. I feel incredibly weak, thirsty, and have a dry mouth. Nausea is also present, and my fever is 100.9°F.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: The illness started yesterday, and it was both abrupt and severe. A fever of 102.8°F, intense aches all over my body, and overwhelming exhaustion hit me. Since then, I've had a persistent, non-productive cough, chills that come and go, and a heavy feeling in my head. I'm completely unable to function.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: A 103.0°F fever has been with me for five days, bringing with it an absolutely splitting headache and an unbearable pain behind my eyes. A profound ache has settled over my entire body, I've had two nosebleeds, and I've become concerned about the small red spots that have started showing up on my legs.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: I've had what I'd call mild diarrhea since yesterday, with about four loose stools. I have some minor stomach cramps and a slight feeling of malaise. I don't have any signs of dehydration or thirst, and my temperature is normal at 98.7°F.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: Throughout this four-day illness, my temperature has been going up and down, ranging from 101.5°F to 103.2°F. What's really concerning is a deep, aching pain that has developed behind my eyes. All my muscles feel sore to the touch, and I just found some tiny, red dots on my stomach that don't itch.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: For the last five days, I've had a fever that keeps climbing and has now reached 104.2°F. Along with the fever, I've had a severe, hacking cough and a profusely runny nose with clear discharge. My eyes are so intensely red that being in a lit room is impossible. About two days ago, I noticed some tiny white spots on the inside of my cheeks. The rash that began behind my ears yesterday has now covered my entire face and is moving down to my chest.
# Expected: Measles
# Predicted: Measles
#
# Row text: Persisting for 5 days, this condition is worsening, and the symptoms are progressive. Every breath is a struggle, and I'm finding it hard to catch my breath due to a sharp pain on my right side that worsens with breathing. My fever of 102.1°F won't break with medication, my cough is bringing up blood-tinged mucus, and I have severe fatigue and body aches.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: This weakness makes me want to just lie here. For the past three days, my fever has hit 102.1°F. An unrelenting cough constantly brings up rust-colored material, and breathing triggers excruciating pain in my mediastinal region, forcing me to take shallow, rapid breaths.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: The weakness is so bad, it's totally debilitating. I've been running a high temperature for 9 days, from 100.3°F to 103.0°F. My head is pounding severely right in the front. My gut is cramping and in pain. I haven't eaten a real meal in days. I was super constipated at first, but then around day 8, I got diarrhea for 2 days.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: I'm severely ill with a fever of 103.9°F and my muscles ache all over my body. Even with heating, I have shaking chills. The dry cough is so bad it's causing rib pain. The exhaustion is so extreme that I've been unconscious for extended periods, and I have a throbbing headache at the back of my head. This decline happened rapidly and is getting worse despite interventions, making it a clear medical emergency
# Expected: Influenza
# Predicted: Influenza
#
# Row text: For about four days, I've had a 102°F fever, a persistent dry cough, a stuffy nose, and my eyes are a little red, much like a bad cold. This morning, a red rash that doesn't itch started behind my ears and on my neck. I don't feel well, but my symptoms aren't severe. Light is somewhat bothersome to my eyes.
# Expected: Measles
# Predicted: Measles
#
# Row text: For eight days now, I've been battling a severe infection with a 104.9°F fever that medicine won't touch. I have a severe cough that feels like I'm constantly clearing my throat, a heavy, clear discharge from my nose, and a bad case of conjunctivitis. My eyes are so sensitive to light that I have to be in complete darkness. On day seven, a rash appeared along my hairline and behind my ears. It now covers my entire face and neck and is reaching my upper chest, with the purple-tinged spots starting to run together. The lymph nodes in my neck are noticeably swollen. I feel completely exhausted, weak, and disoriented.
# Expected: Measles
# Predicted: Measles
#
# Row text: It's a struggle to take every breath; I'm just gasping for air. This started 3 days ago, and the symptoms are getting progressively worse. I have a sharp pain across the front of my chest that hurts more when I try to breathe. On top of that, I have severe fatigue, body aches, a 102.4°F fever, and a productive cough that's bringing up pink-frothy phlegm.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: For a week now, my temperature has been elevated to 103.5°F. I have a constant productive cough bringing up thick, lime-green, foul-smelling sputum. There is a severe, localized stabbing pain in my right chest with any breath. My dyspnea is marked, causing me to breathe rapidly and shallowly. I'm also completely exhausted and nauseous.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: For the past four days, I've been dealing with a dangerously high fever of 104.9°F. Along with the fever, I've developed a severe, barking cough and a constant clear runny nose. My eyes have become swollen and red, and they are extremely painful when exposed to light. Yesterday, a red, blotchy rash appeared on my face, which has now merged and spread to my chest and back.
# Expected: Measles
# Predicted: Measles
#
# Row text: This began three days ago, and my fever is now 100.5°F. I have a moderate cough that produces thick, golden-yellow phlegm constantly. There's a sharp discomfort in my right mid-axillary area, which gets worse with breathing. I'm panting like I've just run a marathon, and my condition feels alarming.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: Since yesterday, I've had a dangerously elevated temperature of 104.6°F accompanied by violent rigors. I am in severe respiratory distress, struggling for every single breath, and any breathing movement causes excruciating pleuritic pain throughout my right chest. I'm coughing up copious amounts of rust-colored, blood-streaked secretions and am also extremely weak with episodes of confusion.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: A fever of 103.5Â°F started suddenly about 48 hours ago. The pain in my joints is excruciating, making it painful to even get out of bed. I have a bad headache and feel dizzy. I have no chest pain or difficulty breathing, and I'm not coughing up any mucus at all.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: Just walking to the bathroom makes me gasp for air, I'm that exhausted. This started 3 days ago. My fever is 101.2°F, and I have this cough that's making me spit up thick white phlegm. There's also a little sharp pain on my left side whenever I breathe in too deep.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: My diarrhea began two days ago, and so far today I've had seven loose bowel movements. I have a general feeling of being unwell and tired, along with a low-grade fever of 100.3°F. The cramping is persistent and uncomfortable, I get dizzy if I stand up too fast, and my mouth and lips are very dry.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: My fever is 102.8°F on this fourth day of being ill. I have an unproductive cough that makes it hard to hold a conversation, and a constant, clear runny nose. Any indoor lighting is enough to make my eyes water. I've confirmed there are no spots in my mouth. A rash that started behind my ears yesterday evening had spread over my entire face by morning, and it is now moving down my neck in the direction of my collarbones. I also get mild body aches just from sitting up.
# Expected: Measles
# Predicted: Measles
#
# Row text: For the last four days, I've had a dry, hacking cough and a constantly runny nose, accompanied by a 103.5°F fever. My eyes feel red and gritty, and the light sensitivity is a significant problem. A red, bumpy rash appeared this morning on my face and behind my ears, and it's now working its way down my neck. I'm also experiencing quite a bit of muscle soreness.
# Expected: Measles
# Predicted: Measles
#
# Row text: Early this morning, I've had six watery stools that have some mucus. The abdominal cramps are moderate. I've felt nauseous all day. I'm also experiencing a low fever of 100.1°F, a general sense of malaise, and my mouth is definitely dry, making me feel thirsty.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: For the past two days, I've been running a slight fever of 100.2°F, and my head has been mildly aching. On top of that, my wrists feel a bit tender, and I just have a general sense of feeling unwell, though there are no other significant issues.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: My fever started about a week ago, initially at 100°F, and has now reached a sustained 104.2°F. I'm dealing with severe head pain and a constant pressure behind my eyes. My stomach, especially the lower left side, is very sore. The weakness is so profound that I am unable to get out of bed. I have completely lost my appetite. Yesterday, I saw some small, faint pink marks on my abdomen. I've also been feeling a bit confused at times.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: For six days now, I've had severe muscle pain and exhaustion, along with respiratory compromise. My fever has been high, reaching 102.7°F. I also have a persistent cough producing thick, pale yellow discharge, and an agonizing, localized pain in my right lower chest that gets worse with deep breaths or coughing.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: On Wednesday during my lunch break, this came out of nowhere. I have a 102.4°F fever, and the pain in my arms and thighs is so severe that I had to crawl to the bathroom. A profound weakness forces me to rest hourly. At 1 PM, a dry cough started up, and I've had violent chills despite being in a warm room. I also have a mild frontal headache. I haven't been able to eat any solid food since this started, which feels surreal because I was energetically leading a meeting just this morning.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: For the past five days, I've been dealing with a 104.5°F fever. The headache is so bad it feels like my head is splitting open, and the pain behind my eyes is unbearable. On top of that, my whole body has a deep ache, I've experienced several nosebleeds, and I'm seeing tiny red spots on my lower legs.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: I've been severely ill for six days with a fever of 104.7°F. My cough is just brutal, and a clear fluid is always running from my nose. My eyes are swollen, and I have an extreme sensitivity to light. The rash started on my face three days ago and has now worked its way down to my legs and feet, with some of the spots starting to blend together. I feel very weak and have had some moments where I feel confused.
# Expected: Measles
# Predicted: Measles
#
# Row text: After nine straight days with a 104.8°F fever, the pain behind my eyes is so severe that I have to keep them shut all the time. Attempting to stand makes my hip joints feel as if they are completely shattered. This morning, my gums bled so much that it filled half a cup with bloody saliva. A petechial rash is now covering every single inch of my visible skin.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: My temperature has been climbing daily for eight days, from 100°F to 103.1°F today. I have severe, constant pain in the front of my head. My lower abdomen is cramping and tender. I feel very weak and fatigued, making it hard to do my usual activities. I've lost all desire to eat, and food just doesn't appeal to me. I was constipated initially, but loose stools started yesterday.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: My wife made me write this down. I've had a fever for eight consecutive days, which started at 99.8 and is now 103.1, getting higher each evening. It feels like my skull is splitting in the middle, with the pain focused right on my forehead. My lower stomach, especially the right side, is extremely tender. I've been too drained to do anything and have missed work for three days in a row. Around the fifth day, I lost all interest in food. The constipation I had for the first part of this has turned into watery and urgent diarrhea since the seventh day. I need to see a doctor.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: I have been dealing with a 103.5°F fever for four days, along with a hacking cough and clear nasal discharge. I also have conjunctivitis with photophobia, which has me keeping the curtains closed. The red rash that started yesterday behind my ears and along my hairline now covers my face and is spreading to my neck and upper chest. I can feel enlarged lymph nodes in my neck. Overall, I feel very unwell.
# Expected: Measles
# Predicted: Measles
#
# Row text: My temperature has been 103.0°F for four days now. I have a dry cough that won't go away, clear stuffiness in my nose, and my eyes are red, sore, and constantly watering—I have to keep the curtains closed because the light is painful. A red, bumpy rash that started yesterday behind my ears and at my hairline is now spreading across my face and down onto my neck. I also have a headache and some mild muscle aches.
# Expected: Measles
# Predicted: Measles
#
# Row text: For the last four days, I've been running a 103.6°F fever and have a hacking cough, a nose running with clear liquid, and red, watery eyes. The light is painful, so I have been staying in a darkened room. A rash that started yesterday at my hairline has now spread over my face and is beginning on my chest. I am feeling completely wiped out.
# Expected: Measles
# Predicted: Measles
#
# Row text: My whole lower belly is super sore, it's been like this for 14 days. I'm also burning up, my temperature started at 101.7°F and now it's 104.8°F. The headache in the front of my head is killing me. I'm so weak I can't even move, and the thought of food makes me sick. Around day 11, little pink spots started showing up on my stomach, and my mind has been really foggy.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: For the last 72 hours, my temperature has been 102.6°F, and the stabbing pain in my eye sockets is so bad that reading is impossible. My wrists feel like they are burning whenever I type. Yesterday, I had a minor nosebleed that lasted for ten minutes. I'm now seeing pinprick-sized red dots appearing all over my abdomen and upper thighs.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: I've been to the bathroom 9 times since I woke up, and my stools are watery with some blood and mucus. The urgency is terrible, and the cramps are so severe I feel like I'm going to faint when I stand. My mouth is completely dry, I haven't urinated in more than 8 hours, and my temperature is 101.5°F.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: On this fifth day of my illness, my temperature has reached 103.9°F. I have a cough that sounds like a seal's bark, and a continuous flow of clear fluid is coming from my nose. My eyes are so bloodshot that even a nightlight causes pain. Two days ago, white dots appeared inside my right cheek. A rash that started at my hairline yesterday morning had spread over my entire face and neck by evening, and today it has reached my navel with flat red spots. I have swollen lymph nodes behind my ears and in my neck.
# Expected: Measles
# Predicted: Measles
#
# Row text: I was playing vigorous tennis Wednesday morning without any warning signs, but then this just erupted during my lunch break. Within two hours, my fever climbed to 101.8°F, and I developed a persistent ache in my arms and spine. The lethargy is noticeable; I can sit up briefly but have zero capacity to cook, which meant I had to miss my childcare duties. Later, a minimal dry cough and slight nasal stuffiness started. I also have some mild pressure in my forehead that pain medicine only partially helps.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: A fever of 102°F started four days ago and has been steady ever since. I'm dealing with a headache that won't stop throbbing and aches all over my body. On top of that, I've been getting occasional mild nosebleeds that started yesterday.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: I've been completely exhausted and barely able to function since last night, when a 102.3°F fever hit me suddenly. It came with severe muscle pain in my back and shaking chills. I also have a dry cough, a runny nose, and a mild headache.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: For three days now, I've been feeling mildly sick with a temperature of 102.1°F. I've had a dry cough that seems to start up when I take a deep breath, and my nose has been running a little with clear discharge. My eyes are a bit red and sensitive to bright screens. I haven't found any Koplik spots. A rash with small, raised red spots appeared this morning, but it's only behind my right ear. There are 3-4 separate red spots, each about 1-2mm wide. The rash hasn't gotten any bigger or spread since this morning. I'm able to work from home with my screens dimmed. I feel mildly fatigued after a shower but am still drinking enough and can take care of my basic needs.
# Expected: Measles
# Predicted: Measles
#
# Row text: My temperature was normal on Saturday, but on Sunday, a 103.0°F fever started, bringing with it pain behind my eyes so severe I'm unable to watch television. In the evenings, my wrist joints swell up to the point where I can't even grip a fork or spoon. Yesterday morning, my nose began bleeding spontaneously, and it took medical tape to make it stop. Today, I've noticed tiny crimson dots beginning to spread across my ribcage.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: This is day five of feeling sick. I'm tired but at least I can still move. My lower belly is a bit sore. The fever is not so high, it's been between 99.6 and 101.3. I have a headache that's just in the front part of my head. I also haven't been able to poop for three days and I really don't feel like eating.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: Yesterday afternoon, this sickness came on very suddenly with a 102.8°F fever, extreme fatigue, and severe muscle aches. Along with that, I have a bad headache, chills, and a dry, hacking cough. I'm completely wiped out and can't do any of my usual activities.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: This high fever has been going on for eight days, staying consistently around 104.2°F. The pain behind my eyes is so excruciating that I have to be in a completely dark room. My joints are incredibly inflamed and painful, making the slightest movement agonizing. I've also had several spontaneous nosebleeds today.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: Within minutes of getting home, my body just erupted with aches. My fever was 102.6°F and still climbing. I'm going between teeth-chattering chills and then getting drenched in sweat. Around dinner time, a dry cough appeared. I'm at the point where I can't do even the simplest tasks by myself.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: A week ago felt kinda off, fever around 99.5. Now it's 102.8 and keeps rising at night. Headache right behind my eyes that just won't quit. Lower belly hurts when I press down. Way too tired, had to call out of work three days running. Can't eat, even water's gross. Five days stuck, totally constipated.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: For nine days now, my temperature has been climbing, starting at 100.9°F and now it's up to 103.8°F. For the first week I was constipated, but that changed to persistent loose stools on day seven. I also have a constant dull ache in the front of my head and I'm just too weak to stand or walk. My gut is cramping and painful, and I can't manage to eat anything at all.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: For the past five days, I've had a continuous and extremely high fever of 105.1°F. My dry cough is incessant, and my nose is constantly streaming clear fluid. My eyes are so swollen and painful that I have to remain in complete darkness. Just before the rash appeared, I noticed tiny white dots inside my cheeks. The rash itself has now spread from my face down to my arms and the spots are beginning to merge.
# Expected: Measles
# Predicted: Measles
#
# ...
# Expected: Influenza
# Predicted: Influenza
#
# Row text: Since last night, I've had to go about six times with very loose diarrhea. I feel queasy and am running a low-grade fever of 100.0°F. The abdominal cramps are quite uncomfortable, and I'm thirsty to the point where my mouth feels like sandpaper.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: My temperature has been stuck at a stubborn 103.1°F for six days straight. There's a constant pressure behind my eyeballs that makes it impossible to look at any screens. The ache in my shoulder joints is so intense that I can't raise my arms over my head. Yesterday, my gums started bleeding on their own and didn't stop for more than fifteen minutes, even with ice. The fatigue is so bad I'm sleeping for eighteen hours every day.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: I'm so tired, but I can still do some things. It's been seven days of this fever, which started at 99°F and went up to 102.3°F. My forehead has a headache that just stays. My lower stomach is a little uncomfortable and slightly sore. I've definitely lost a lot of my appetite. I also haven't pooped in three days.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: So many things are wrong with me. My mind is so foggy that I missed my doctor's appointment today. It's been seven days of being sick. The fever started at 99.9°F and is now 102.5°F. My head is pounding behind my eyes. My belly is sore when I sit. I'm too exhausted to even watch TV. I can only eat the crusts of toast. I've been constipated for the entire week.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: For the last 5 days, I've been feeling progressively worse and increasingly unwell. I have weakness and a fever with teeth-chattering chills that climbs to 104.1°F and won't break with medicine. My breathing is rapid and shallow, I can't stop coughing up bright yellow material, and every breath triggers a knife-like sensation in both sides of my chest.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: I've had a 102.5°F fever for exactly 72 hours, accompanied by a crushing pressure behind my eyeballs. Just walking to the bathroom causes the tendons in my ankles to scream in protest. I noticed tiny spots of blood on my toothbrush yesterday morning. While I haven't developed a rash, the weakness is so profound that trying to hold a spoon feels like lifting heavy weights.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: For about a week now, my symptoms have been getting progressively worse. I've had a fever of 102.2°F that just won't break with medication. I'm panting because every breath is a struggle, and there's an excruciating pain across my left pleural area that gets worse when I breathe. I'm also severely fatigued with body aches and have a productive cough that brings up rusty sputum.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: I've had profuse, watery diarrhea at least nine times since this morning, and the cramping is intense. The urgency is so sudden that I've had an accident. Every time I move, I feel dizzy. I'm also completely exhausted, extremely thirsty with a very dry mouth, and have a fever of 101.5°F.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: This is day two of a severe illness, with my temperature at 104.6°F. I have a productive, severe cough that is bringing up a pinkish discharge. There is a localized, intense discomfort across my left lung area that gets considerably worse with deep breathing. I'm experiencing air hunger between coughs, and this is seriously affecting my ability to function.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: In the last twelve hours, I've had six bouts of watery stools. I'm dealing with moderate cramping and a feeling of nausea. My thirst is significant, and I've noticed my urine is darker than it usually is. While I feel weak, I have not developed a fever. The constant urgency is making me worried about being far from a bathroom.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: This began overnight with intense, watery diarrhea; I've been about 8 times so far. I've noticed streaks of blood and mucus in it. The pain in my abdomen is sharp and crampy. Each time, I get a sudden, urgent need to go to the bathroom. I'm extremely thirsty, my mouth is parched, and I'm feeling lightheaded. I also feel very sick and have a fever of about 101.2°F.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: My head feels like it's being crushed, the pain is right in my forehead. It's day 7 of this. The fever was 100.2°F this morning and now it's 102.5°F. I'm so weak, my legs feel like jelly. I haven't really eaten since Tuesday. My lower belly hurts so bad when I touch it. I was constipated from Wednesday to Saturday, but today, I have watery diarrhea and have to keep running to the bathroom. I can't even focus enough to read the newspaper.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: A persistent dry cough has accompanied my 103°F fever for the last four days. I also have a stuffy nose with clear drainage and very red eyes that are bothered by light. Yesterday, a red, bumpy rash broke out behind my ears; it has now spread across my face and is beginning to creep down my neck. On top of that, I'm feeling mild aches in my muscles and have a headache.
# Expected: Measles
# Predicted: Measles
#
# Row text: Over the past 10 days, I've had a fever that increases daily, going from 100°F to 104.2°F. A severe, pounding headache is affecting the entire front of my head. My stomach, particularly the lower right side, is tender to the touch. The weakness is so overwhelming that it has left me debilitated, and I have lost all interest in food. I noticed small pink spots on my belly yesterday, and I have been experiencing moments of confusion.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: It started as a cold about a week ago, but for the last three days, it's gotten much worse. I have a high fever, chills, and a cough that produces greenish mucus. I'm having trouble breathing, and there's a sharp pain in my chest when I cough. My bowel movements are normal and formed.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: I've had five loose, watery bowel movements today, which is not normal for me at all. I'm also experiencing some cramping in my abdomen. A feeling of nausea has come over me, and I'm thirsty with a dry mouth. On top of that, I've been running a slight fever of 99.8°F.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: This is the sixth day of a severe infection, and my fever is 105.2°F, which no medication has helped. The cough has gotten violent and comes in fits that are so bad they cause me to pass out. There is a profuse, clear discharge from my nose. My eyes are completely swollen shut, and I have an extreme sensitivity to light. On day two, Koplik spots were visible on my inner cheeks. The rash started at my hairline on day three, moved down to my face and neck by day four, and then to my chest and abdomen by day five. Now, my entire body is blanketed in confluent purple lesions that show widespread tissue death. I am in a coma and require intensive care.
# Expected: Measles
# Predicted: Measles
#
# Row text: This hit me yesterday morning and has gotten worse so fast. I have a high fever of 102.3°F and I'm coughing up rust-colored mucus. Every time I cough or take a deep breath, I get a sharp, stabbing sensation in my chest. My breathing is rapid and shallow, and I feel a general sense of malaise and weakness. I'm really struggling; this is very uncomfortable and the symptoms are severe.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: It started three days ago with a fever of 102.3°F. Along with a severe headache, my joints are in a lot of pain, particularly my knees. I also have a distinct pain in the area behind my eyes. I've been feeling extremely sick to my stomach and did throw up one time.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: Since this morning, I've had five loose, watery stools. The moderate cramping seems to come and go. Along with nausea, I have a headache. My mouth is dry, and I'm more thirsty than usual. I feel weak all over, and my temperature is 99.8°F. It all started very suddenly.
# Expected: Diarrhea
# Predicted: Diarrhea
#
# Row text: It's hard to get a full breath, and I have this wet cough that won't stop. It started about five days ago. I feel feverish and have a sharp pain in my chest when I breathe deeply. I don't have any kind of salmon-colored spots on my stomach.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: This is day four, and my temperature is 104.3°F. My cough is so bad I can't drink any fluids. There is a constant drip of clear fluid from my nose. My eyes are completely swollen shut from light sensitivity, so I have to stay in pitch darkness. On the second day, I noticed tiny white dots inside my mouth. A rash began behind my ears on the morning of day three, enveloped my entire head and neck by that evening, and has now spread to my pelvis with purple lesions that have flowed together. I am unable to remember my own name.
# Expected: Measles
# Predicted: Measles
#
# Row text: About two days ago, I came down with a low-grade fever of 100.8°F and a dull headache. My shoulders and neck feel a little sore, though it’s not severe. I’ve also had a slight cough, and lately my appetite’s been lower than usual. I’m somewhat tired, but I’m still able to go about my day.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: This infection took hold in just 120 minutes. I have a 104.0°F fever and a deep muscle pain that doesn't get better no matter how I try to position myself. The weakness is so bad I can't function on my own. After the fever started, I developed an exhausting, non-productive cough. I'm having profound episodes of rigors. Even with interventions, my symptoms persist, and I require comprehensive care; this feels like a medical emergency.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: This fever is so high, 103.4°F, and it's been going on for 6 days. I'm so weak I can barely move. Every time I cough, I bring up this rusty-colored phlegm. Any movement at all causes a super sharp stabbing pain in my chest, and I'm really fighting to get a good breath.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: This 103.2°F fever has been going on for four days, along with a pounding headache. The pain behind my eyes is intense, and my knees and elbows throb so much it's very difficult to move. Yesterday, small red spots started to appear on my arms. I've also been feeling quite nauseous and have no desire to eat.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: While I was on my way to work Thursday, this came out of nowhere. My temperature is 102.1°F, and the severe pain in my shoulders and legs means I need assistance to walk. Due to profound weakness, I have to rest on an hourly basis. A dry, non-productive cough appeared after the fever, and I've had moderate chills even though I was dressed warmly. I also have a mild frontal headache. As a result, I missed an important meeting, which is a stark contrast to how energetic I felt driving to the office that same morning.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: This has been going on for six days, and I'm still running a 104.8°F fever. The cough is vicious, my nose is like a non-stop faucet with clear liquid, and my eyes are swollen and extremely sensitive to light. The rash, which first showed up on my face three days ago, has now moved down to my legs, and some of the spots are starting to merge together.
# Expected: Measles
# Predicted: Measles
#
# Row text: It started on Thursday morning with chills that soon developed into a 103.5°F fever. By the next day, Friday, moving my head caused a stabbing pain deep within my eye sockets, and my wrists were so swollen I couldn't even twist a doorknob. I experienced my first nosebleed this morning, which lasted for twelve minutes, and now my abdomen is covered in scattered red dots that look like cayenne pepper was sprinkled on it.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: For the past ten days of my illness, my temperature has steadily climbed from 100.7°F to 103.3°F. I have zero appetite, and the very thought of food makes me sick. I was severely constipated initially, but for the last two days, it has turned into diarrhea. A constant dull ache is present behind my eyes and forehead. I am also experiencing profound fatigue that makes it difficult to move, and my lower abdomen is severely tender.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: It came on with terrifying speed Tuesday night. I have a 103.7°F fever, and the bone-rattling chills prevented me from getting any sleep. There is excruciating pain in every single muscle fiber, but it's most intense in my hamstrings. I'm so exhausted I can't even lift my head from the pillow. A dry, barking cough is now triggering discomfort in my chest. This sudden collapse is the complete opposite of that evening when I was at the theater. After 30 hours, I'm in total prostration with a persistent high fever.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: Continuing for 6 days, I've had a pronounced fever of 102.8°F. I am profoundly tired, and it is extremely difficult to get enough air. I have a persistent, productive cough bringing up discolored yellow mucus, and there's a sharp, knife-like pleuritic pain. The symptoms are severe, and everything feels worse.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: Since yesterday, I've had watery diarrhea and cramps in my stomach. I've vomited once and continue to feel nauseous. I don't have a high fever, but I do feel a bit warm. I haven't seen any rash or had any bleeding.
# Expected: Dengue
# Predicted: Dengue
#
# Row text: For the past nine days, my temperature has been rising every single evening, beginning at 99.5°F and hitting 103°F yesterday. I have a relentless, pounding headache right at the front of my head. There's stomach pain in my lower abdomen, and it's noticeably tender when I press on it. I feel completely drained and can't manage my daily tasks. I've lost all desire to eat anything. Early on, I couldn't pass stool for three days.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: I've had a minimal dry cough since this morning, but this afternoon everything else hit me at once. A fever of 101.2°F started suddenly, along with moderate aches all over and a feeling of considerable fatigue. There are no chills, no headache, and my throat isn't sore, but the suddenness of it all and the body aches are unmistakable.
# Expected: Influenza
# Predicted: Influenza
#
# Row text: For the past five days, my temperature has been 103.8°F with ongoing shaking chills. A persistent cough brings up thick, dark brown purulent sputum. I have severe, knife-like pleuritic pain in my left chest wall when I breathe. My breathing is rapid and labored, and I'm having difficulty getting enough air. I am totally exhausted and have severe body aches.
# Expected: Pneumonia
# Predicted: Pneumonia
#
# Row text: I've been dealing with a high fever for seven consecutive days, which began at 100.5°F and has now reached 102.8°F. A constant and quite bothersome headache is affecting the front of my head. My lower belly hurts and feels somewhat tender. I'm very tired, finding it difficult to get through my daily routine. My appetite has almost completely vanished. For four days, I haven't been able to have a bowel movement due to constipation.
# Expected: Typhoid
# Predicted: Typhoid
#
# Row text: My fever's been 103.2°F for 24 hours with crazy shaking chills. I'm coughing up thick green mucus. The right side of my chest has this super sharp stabbing pain that gets worse when I breathe in. I can't catch my breath even when I'm just sitting still.
# Expected: Pneumonia
# Predicted: Pneumonia

# %%
# Function to check for overlaps between two datasets
def check_overlap(dataset1, dataset2, split1_name, split2_name):
    set1 = set(dataset1['text'])
    set2 = set(dataset2['text'])
    overlap = set1.intersection(set2)
    if overlap:
        print(f"Overlap found between {split1_name} and {split2_name}: {len(overlap)} overlapping examples:")
        print(overlap)
    else:
        print(f"No overlap found between {split1_name} and {split2_name}.")

# Check for overlaps between the splits, mukhang isa lang naman yung naging overlap, the rest mukhang completely separate data na so parang ok naman yon i think
check_overlap(dataset['train'], dataset['validation'], 'train', 'validation')
check_overlap(dataset['train'], dataset['test'], 'train', 'test')
check_overlap(dataset['validation'], dataset['test'], 'validation', 'test')
# Out:
# No overlap found between train and validation.
# No overlap found between train and test.
# No overlap found between validation and test.

# %% [markdown]
# # 🚀 Deployment to Hugging Face Hub
#
# Publish the fine‑tuned model for reuse and transparency.
#
# **Repo**: `notlath/BioClinical-ModernBERT-base-Symptom2Disease_WITH-DROPOUT`
#
# **Steps**
# 1. Authenticate with a secure Hugging Face token (never hard‑code in shared notebooks; use env var or input prompt).
# 2. Call `trainer.push_to_hub()` (auto‑uploads model + tokenizer + config).
# 3. If that fails, manually load from `final_model_train/` and push model + tokenizer.
# 4. Verify `config.json` lists all dropout params (attention, mlp, embedding, classifier = 0.1).
#
# **Post‑Upload Checklist**
# - Model card updated (add task, dataset citation, metrics, limitations).
# - License + intended use documented.
# - Example inference snippet works via `pipeline()`.
#
# Outcome: Public, reproducible artifact ready for downstream evaluation.

# %%
from huggingface_hub import login

# Paste your token here - Get from https://huggingface.co/settings/tokens
token = "YOUR_HF_TOKEN_HERE"  # Replace with your actual token
login(token=token)

# Verify it worked
from huggingface_hub import whoami
try:
    user = whoami()
    print(f"✅ Logged in as: {user['name']}")
except Exception as e:
    print(f"❌ Login failed: {e}")

# Push model using trainer.push_to_hub() - this ensures the trained model is pushed
repo_name = "notlath/BioClinical-ModernBERT-base-Symptom2Disease_WITHOUT-DROPOUT-42"

print("🚀 Pushing model to Hugging Face...")
try:
    # Method 1: Use trainer.push_to_hub() (recommended)
    trainer.push_to_hub(repo_name, token=token)
    print(f"✅ Successfully pushed model using trainer.push_to_hub() to {repo_name}")
except Exception as e:
    print(f"❌ trainer.push_to_hub() failed: {e}")
    print("🔄 Trying alternative method...")

    # Method 2: Alternative - push model and tokenizer separately from the saved directory
    try:
        from transformers import AutoModelForSequenceClassification, AutoTokenizer

        # Load the saved model with correct dropout config
        saved_model = AutoModelForSequenceClassification.from_pretrained("./final_model_train")
        saved_tokenizer = AutoTokenizer.from_pretrained("./final_model_train")

        # Push the saved model and tokenizer
        saved_model.push_to_hub(repo_name, token=token)
        saved_tokenizer.push_to_hub(repo_name, token=token)
        print(f"✅ Successfully pushed model using alternative method to {repo_name}")

    except Exception as e2:
        print(f"❌ Alternative method also failed: {e2}")

print("\n📋 Verify your model config includes all dropout parameters:")
print("Visit: https://huggingface.co/" + repo_name + "/blob/main/config.json")

# Load the model config to get actual dropout values
from transformers import AutoConfig
try:
    # Try to load from the pushed model on HuggingFace
    config = AutoConfig.from_pretrained(repo_name)
    print("✅ Loaded config from HuggingFace Hub")
except:
    # Fallback to local model if HuggingFace fails
    config = AutoConfig.from_pretrained("./final_model_train")
    print("✅ Loaded config from local model")

print("Actual dropout parameters:")
print(f"- attention_dropout: {getattr(config, 'attention_dropout', 'Not found')}")
print(f"- mlp_dropout: {getattr(config, 'mlp_dropout', 'Not found')}")
print(f"- embedding_dropout: {getattr(config, 'embedding_dropout', 'Not found')}")
print(f"- classifier_dropout: {getattr(config, 'classifier_dropout', 'Not found')}")

# Also show hidden_dropout_prob if available (common BERT parameter)
if hasattr(config, 'hidden_dropout_prob'):
    print(f"- hidden_dropout_prob: {config.hidden_dropout_prob}")
# Out:
# ✅ Logged in as: notlath
# 🚀 Pushing model to Hugging Face...
# ❌ trainer.push_to_hub() failed: (Request ID: Root=1-690ac73d-7362f995365b989144af3b58;6108bd34-1621-48db-a4ff-798182b0e443)
#
# 403 Forbidden: You have read access but not the required permissions for this operation.
# Cannot access content at: https://huggingface.co/rchrdwllm/BioClinical-ModernBERT-base-Symptom2Disease_WITHOUT-DROPOUT-42.git/info/lfs/objects/batch.
# Make sure your token has the correct permissions.
# 🔄 Trying alternative method...
# README.md: 0.00B [00:00, ?B/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...n6fwhlv/model.safetensors:   0%|          |  553kB /  598MB
# ✅ Successfully pushed model using alternative method to notlath/BioClinical-ModernBERT-base-Symptom2Disease_WITHOUT-DROPOUT-42
#
# 📋 Verify your model config includes all dropout parameters:
# Visit: https://huggingface.co/notlath/BioClinical-ModernBERT-base-Symptom2Disease_WITHOUT-DROPOUT-42/blob/main/config.json
# config.json: 0.00B [00:00, ?B/s]
# ✅ Loaded config from HuggingFace Hub
# Actual dropout parameters:
# - attention_dropout: 0.0
# - mlp_dropout: 0.0
# - embedding_dropout: 0.0
# - classifier_dropout: 0.0

# %% [markdown]
# ### Calibration Analysis

# %%
from sklearn.calibration import calibration_curve
import matplotlib.pyplot as plt
import torch

# Get probability scores
probs = torch.softmax(torch.tensor(predictions), dim=-1).numpy()
max_probs = probs.max(axis=1)

# Plot reliability diagram
plt.hist(max_probs, bins=20)
plt.xlabel('Predicted Probability')
plt.ylabel('Count')
plt.title('Confidence Distribution')
# Out:
# Text(0.5, 1.0, 'Confidence Distribution')

# %% [markdown]
# ### Error Analysis by Symptom Overlap

# %%
# Add after confusion matrix
import pandas as pd

# Find most common misclassifications
errors = []
for i in range(len(y_true)):
    if y_true[i] != y_pred[i]:
        errors.append({
            'true': id2label[y_true[i]],
            'predicted': id2label[y_pred[i]],
            'text': dataset['test'][i]['text']
        })

error_df = pd.DataFrame(errors)
print(error_df['true'].value_counts())
print("\nMost common confusions:")
print(error_df.groupby(['true', 'predicted']).size().sort_values(ascending=False).head(10))
# Out:
# true
# Influenza    5
# Measles      2
# Dengue       2
# Name: count, dtype: int64
#
# Most common confusions:
# true       predicted
# Influenza  Measles      5
# Measles    Influenza    2
# Dengue     Typhoid      1
#            Measles      1
# dtype: int64
